# %% [markdown]
# # Inference and Validation
#
# Now that you have a trained network, you can use it for making predictions. This is typically called **inference**, a term borrowed from statistics. However, neural networks have a tendency to perform *too well* on the training data and aren't able to generalize to data that hasn't been seen before. This is called **overfitting** and it impairs inference performance. To test for overfitting while training, we measure the performance on data not in the training set called the **validation** set. We avoid overfitting through regularization such as dropout while monitoring the validation performance during training. In this notebook, I'll show you how to do this in PyTorch.
#
# As usual, let's start by loading the dataset through torchvision. You'll learn more about torchvision and loading data in a later part. This time we'll be taking advantage of the test set which you can get by setting `train=False` here:
#
# ```python
# testset = datasets.FashionMNIST('~/.pytorch/F_MNIST_data/', download=True, train=False, transform=transform)
# ```
#
# The test set contains images just like the training set. Typically you'll see 10-20% of the original dataset held out for testing and validation with the rest being used for training.

# %%
import torch
from torchvision import datasets, transforms

# Define a transform to normalize the data
transform = transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.5,), (0.5,))])
# Download and load the training data
trainset = datasets.FashionMNIST("~/.pytorch/F_MNIST_data/", download=True, train=True, transform=transform)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=64, shuffle=True)

# Download and load the test data
testset = datasets.FashionMNIST("~/.pytorch/F_MNIST_data/", download=True, train=False, transform=transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=64, shuffle=True)

# %% [markdown]
# Here I'll create a model like normal, using the same one from my solution for part 4.

# %%
from torch import nn, optim
from torch.nn.functional import log_softmax, relu


class Classifier(nn.Module):
    """Classifier network with dropout."""

    def __init__(self) -> None:
        super().__init__()
        self.fc1 = nn.Linear(784, 256)
        self.fc2 = nn.Linear(256, 128)
        self.fc3 = nn.Linear(128, 64)
        self.fc4 = nn.Linear(64, 10)

    def forward(self, x):
        """Forward pass through the network, returns the output logits."""
        # make sure input tensor is flattened
        x = x.view(x.shape[0], -1)

        x = relu(self.fc1(x))
        x = relu(self.fc2(x))
        x = relu(self.fc3(x))
        return log_softmax(self.fc4(x), dim=1)

# %% [markdown]
# The goal of validation is to measure the model's performance on data that isn't part of the training set. Performance here is up to the developer to define though. Typically this is just accuracy, the percentage of classes the network predicted correctly. Other options are [precision and recall](https://en.wikipedia.org/wiki/Precision_and_recall#Definition_(classification_context)) and top-5 error rate. We'll focus on accuracy here. First I'll do a forward pass with one batch from the test set.

# %%
model = Classifier()

images, labels = next(iter(testloader))
# Get the class probabilities
ps = torch.exp(model(images))
# Make sure the shape is appropriate, we should get 10 class probabilities for 64 examples
print(ps.shape)
# Out:
# torch.Size([64, 10])

# %% [markdown]
# With the probabilities, we can get the most likely class using the `ps.topk` method. This returns the $k$ highest values. Since we just want the most likely class, we can use `ps.topk(1)`. This returns a tuple of the top-$k$ values and the top-$k$ indices. If the highest value is the fifth element, we'll get back 4 as the index.

# %%
top_p, top_class = ps.topk(1, dim=1)
# Look at the most likely classes for the first 10 examples
print(top_class[:10, :])

# Each [number] is the predicted class
# Out:
# tensor([[9],
#         [9],
#         [9],
#         [7],
#         [9],
#         [9],
#         [9],
#         [9],
#         [9],
#         [9]])

# %% [markdown]
# Now we can check if the predicted classes match the labels. This is simple to do by equating `top_class` and `labels`, but we have to be careful of the shapes. Here `top_class` is a 2D tensor with shape `(64, 1)` while `labels` is 1D with shape `(64)`. To get the equality to work out the way we want, `top_class` and `labels` must have the same shape.
#
# If we do
#
# ```python
# equals = top_class == labels
# ```
#
# `equals` will have shape `(64, 64)`, try it yourself. What it's doing is comparing the one element in each row of `top_class` with each element in `labels` which returns 64 True/False boolean values for each row. To avoid this, we use the `.view` method on `labels` to turn it into the same shape as `top_class`. (The `*top_class.shape` unpacks the shape values, so in this case it's the same as writing `labels.view(64, 1)`).

# %%
equals = top_class == labels.view(*top_class.shape)

# %% [markdown]
# Now we need to calculate the percentage of correct predictions. `equals` has binary values, either 0 or 1. This means that if we just sum up all the values and divide by the number of values, we get the percentage of correct predictions. This is the same operation as taking the mean, so we can get the accuracy with a call to `torch.mean`. If only it was that simple. If you try `torch.mean(equals)`, you'll get an error
#
# ```
# RuntimeError: mean is not implemented for type torch.ByteTensor
# ```
#
# This happens because `equals` has type `torch.ByteTensor` but `torch.mean` isn't implemented for tensors with that type. So we'll need to convert `equals` to a float tensor. Note that when we take `torch.mean` it returns a scalar tensor, to get the actual value as a float we'll need to do `accuracy.item()`.

# %%
accuracy = torch.mean(equals.type(torch.FloatTensor))
print(f"Accuracy: {accuracy.item() * 100}%")
# Out:
# Accuracy: 12.5%

# %% [markdown]
# The network is untrained so it's making random guesses and we should see an accuracy around 10%. Now let's train our network and include our validation pass so we can measure how well the network is performing on the test set. Since we're not updating our parameters in the validation pass, we can speed up our code by turning off gradients using `torch.no_grad()`:
#
# ```python
# # turn off gradients
# with torch.no_grad():
#     # validation pass here
#     for images, labels in testloader:
#         ...
# ```
#
# >**Exercise:** Implement the validation loop below and print out the total accuracy after the loop. You can largely copy and paste the code from above, but I suggest typing it in because writing it out yourself is essential for building the skill. In general you'll always learn more by typing it rather than copy-pasting. You should be able to get an accuracy above 80%.

# %%
import torch.nn.functional as F
model = Classifier()
criterion = nn.NLLLoss()
optimizer = optim.Adam(model.parameters(), lr=0.003)

epochs = 30
steps = 0

train_losses, test_losses = [], []
for _ in range(epochs):
    running_loss = 0
    for images, labels in trainloader:
        optimizer.zero_grad()

        log_ps = model(images)
        loss = criterion(log_ps, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item()

    else:
        ## TODO: Implement the validation pass and print out the validation accuracy
        with torch.no_grad():
            for images, labels in testloader:            
                ps = torch.exp(model(images))
                # ps.shape == (64, 10), assuming batch_size = 64 and class = 10
                # Each row is an image, each column is a class
                # A ps row could look like: [0.01, 0.02, 0.05, 0.10, 0.03, 0.04, 0.60, 0.08, 0.04, 0.03]

                top_p, top_class = ps.topk(1, dim=1)
                # top_k: values, indices = tensor.topk(k, dim)
                # Where k = how many largest values we want
                # dim is along which dimension to look

                # top_p.shape will be (64, 1)
                # Each entry for top_p takes the highest probability predicted for that image

                # top_class.shape is also (64, 1)
                # Each entry for top_class is the index of the class with highest probability


                equals = top_class == labels.view(*top_class.shape)
                accuracy = torch.mean(equals.type(torch.FloatTensor))
                print(f"Accuracy: {accuracy.item() * 100}%")
# Out:
# Accuracy: 85.9375%
# Accuracy: 93.75%
# Accuracy: 89.0625%
# Accuracy: 85.9375%
# Accuracy: 76.5625%
# Accuracy: 68.75%
# Accuracy: 87.5%
# Accuracy: 82.8125%
# Accuracy: 89.0625%
# Accuracy: 87.5%
# Accuracy: 89.0625%
# Accuracy: 85.9375%
# Accuracy: 85.9375%
# Accuracy: 92.1875%
# Accuracy: 78.125%
# Accuracy: 87.5%
# Accuracy: 79.6875%
# Accuracy: 87.5%
# Accuracy: 84.375%
# Accuracy: 87.5%
# Accuracy: 82.8125%
# Accuracy: 79.6875%
# Accuracy: 81.25%
# Accuracy: 87.5%
# Accuracy: 90.625%
# Accuracy: 85.9375%
# Accuracy: 85.9375%
# Accuracy: 85.9375%
# Accuracy: 81.25%
# Accuracy: 87.5%
# Accuracy: 73.4375%
# Accuracy: 76.5625%
# Accuracy: 87.5%
# Accuracy: 79.6875%
# Accuracy: 89.0625%
# Accuracy: 87.5%
# Accuracy: 82.8125%
# Accuracy: 84.375%
# Accuracy: 76.5625%
# Accuracy: 85.9375%
# Accuracy: 71.875%
# Accuracy: 87.5%
# Accuracy: 82.8125%
# Accuracy: 87.5%
# Accuracy: 79.6875%
# Accuracy: 78.125%
# Accuracy: 87.5%
# Accuracy: 89.0625%
# Accuracy: 85.9375%
# Accuracy: 79.6875%
# Accuracy: 84.375%
# Accuracy: 90.625%
# Accuracy: 78.125%
# Accuracy: 81.25%
# Accuracy: 84.375%
# Accuracy: 78.125%
# Accuracy: 71.875%
# Accuracy: 84.375%
# Accuracy: 85.9375%
# Accuracy: 84.375%
# Accuracy: 81.25%
# Accuracy: 75.0%
# Accuracy: 81.25%
# Accuracy: 76.5625%
# Accuracy: 84.375%
# Accuracy: 85.9375%
# Accuracy: 84.375%
# Accuracy: 87.5%
# Accuracy: 90.625%
# Accuracy: 87.5%
# Accuracy: 85.9375%
# Accuracy: 75.0%
# Accuracy: 81.25%
# Accuracy: 81.25%
# Accuracy: 87.5%
# Accuracy: 87.5%
# Accuracy: 82.8125%
# Accuracy: 81.25%
# Accuracy: 84.375%
# Accuracy: 82.8125%
# Accuracy: 78.125%
# Accuracy: 82.8125%
# Accuracy: 82.8125%
# Accuracy: 79.6875%
# Accuracy: 81.25%
# Accuracy: 82.8125%
# Accuracy: 76.5625%
# Accuracy: 82.8125%
# Accuracy: 84.375%
# Accuracy: 84.375%
# Accuracy: 87.5%
# Accuracy: 82.8125%
# Accuracy: 87.5%
# Accuracy: 87.5%
# Accuracy: 81.25%
# Accuracy: 81.25%
# Accuracy: 82.8125%
# Accuracy: 84.375%
# Accuracy: 87.5%
# Accuracy: 78.125%
# Accuracy: 79.6875%
# Accuracy: 81.25%
# Accuracy: 87.5%
# Accuracy: 87.5%
# Accuracy: 79.6875%
# Accuracy: 89.0625%
# Accuracy: 87.5%
# Accuracy: 89.0625%
# Accuracy: 87.5%
# Accuracy: 81.25%
# Accuracy: 85.9375%
# Accuracy: 82.8125%
# Accuracy: 85.9375%
# Accuracy: 82.8125%
# Accuracy: 82.8125%
# Accuracy: 85.9375%
# Accuracy: 85.9375%
# Accuracy: 75.0%
# Accuracy: 76.5625%
# Accuracy: 89.0625%
# Accuracy: 71.875%
# Accuracy: 79.6875%
# Accuracy: 84.375%
# Accuracy: 85.9375%
# Accuracy: 92.1875%
# Accuracy: 78.125%
# Accuracy: 82.8125%
# Accuracy: 93.75%
# Accuracy: 84.375%
# Accuracy: 89.0625%
# Accuracy: 87.5%
# Accuracy: 84.375%
# Accuracy: 78.125%
# Accuracy: 82.8125%
# Accuracy: 75.0%
# Accuracy: 84.375%
# Accuracy: 84.375%
# Accuracy: 84.375%
# Accuracy: 90.625%
# Accuracy: 76.5625%
# Accuracy: 85.9375%
# Accuracy: 84.375%
# Accuracy: 81.25%
# Accuracy: 82.8125%
# Accuracy: 75.0%
# Accuracy: 85.9375%
# Accuracy: 89.0625%
# Accuracy: 84.375%
# Accuracy: 79.6875%
# Accuracy: 76.5625%
# Accuracy: 87.5%
# Accuracy: 90.625%
# Accuracy: 85.9375%
# Accuracy: 87.5%
# Accuracy: 85.9375%
# Accuracy: 87.5%
# Accuracy: 93.75%
# Accuracy: 82.8125%
# Accuracy: 85.9375%
# Accuracy: 87.5%
# Accuracy: 84.375%
# Accuracy: 81.25%
# Accuracy: 85.9375%
# Accuracy: 87.5%
# Accuracy: 84.375%
# Accuracy: 90.625%
# Accuracy: 85.9375%
# Accuracy: 84.375%
# Accuracy: 87.5%
# Accuracy: 81.25%
# Accuracy: 89.0625%
# Accuracy: 87.5%
# Accuracy: 85.9375%
# Accuracy: 78.125%
# Accuracy: 85.9375%
# Accuracy: 84.375%
# Accuracy: 79.6875%
# Accuracy: 89.0625%
# Accuracy: 84.375%
# Accuracy: 90.625%
# Accuracy: 93.75%
# Accuracy: 85.9375%
# Accuracy: 87.5%
# Accuracy: 84.375%
# Accuracy: 93.75%
# Accuracy: 85.9375%
# Accuracy: 81.25%
# Accuracy: 87.5%
# Accuracy: 85.9375%
# Accuracy: 92.1875%
# Accuracy: 85.9375%
# Accuracy: 78.125%
# Accuracy: 95.3125%
# Accuracy: 85.9375%
# Accuracy: 84.375%
# Accuracy: 84.375%
# Accuracy: 85.9375%
# Accuracy: 92.1875%
# Accuracy: 82.8125%
# Accuracy: 84.375%
# Accuracy: 82.8125%
# Accuracy: 82.8125%
# Accuracy: 84.375%
# Accuracy: 87.5%
# Accuracy: 82.8125%
# Accuracy: 92.1875%
# Accuracy: 85.9375%
# Accuracy: 84.375%
# Accuracy: 90.625%
# Accuracy: 76.5625%
# Accuracy: 85.9375%
# Accuracy: 78.125%
# Accuracy: 89.0625%
# Accuracy: 85.9375%
# Accuracy: 87.5%
# Accuracy: 78.125%
# Accuracy: 87.5%
# Accuracy: 78.125%
# Accuracy: 84.375%
# Accuracy: 79.6875%
# Accuracy: 79.6875%
# Accuracy: 75.0%
# Accuracy: 79.6875%
# Accuracy: 90.625%
# Accuracy: 89.0625%
# Accuracy: 95.3125%
# Accuracy: 90.625%
# Accuracy: 84.375%
# Accuracy: 87.5%
# Accuracy: 87.5%
# Accuracy: 85.9375%
# Accuracy: 84.375%
# Accuracy: 82.8125%
# Accuracy: 76.5625%
# Accuracy: 84.375%
# Accuracy: 84.375%
# Accuracy: 84.375%
# Accuracy: 81.25%
# Accuracy: 87.5%
# Accuracy: 92.1875%
# Accuracy: 78.125%
# Accuracy: 90.625%
# Accuracy: 90.625%
# Accuracy: 85.9375%
# Accuracy: 85.9375%
# Accuracy: 84.375%
# Accuracy: 84.375%
# Accuracy: 85.9375%
# Accuracy: 81.25%
# Accuracy: 81.25%
# Accuracy: 82.8125%
# Accuracy: 85.9375%
# Accuracy: 87.5%
# Accuracy: 82.8125%
# Accuracy: 84.375%
# Accuracy: 89.0625%
# Accuracy: 89.0625%
# Accuracy: 89.0625%
# Accuracy: 84.375%
# Accuracy: 85.9375%
# Accuracy: 82.8125%
# Accuracy: 87.5%
# Accuracy: 78.125%
# Accuracy: 78.125%
# Accuracy: 81.25%
# Accuracy: 84.375%
# Accuracy: 78.125%
# Accuracy: 84.375%
# Accuracy: 82.8125%
# Accuracy: 81.25%
# Accuracy: 82.8125%
# Accuracy: 81.25%
# Accuracy: 84.375%
# Accuracy: 85.9375%
# Accuracy: 84.375%
# Accuracy: 87.5%
# Accuracy: 82.8125%
# Accuracy: 82.8125%
# Accuracy: 82.8125%
# Accuracy: 87.5%
# Accuracy: 82.8125%
# Accuracy: 89.0625%
# Accuracy: 81.25%
# Accuracy: 81.25%
# Accuracy: 89.0625%
# Accuracy: 75.0%
# Accuracy: 85.9375%
# Accuracy: 87.5%
# Accuracy: 85.9375%
# Accuracy: 82.8125%
# Accuracy: 87.5%
# Accuracy: 89.0625%
# Accuracy: 76.5625%
# Accuracy: 84.375%
# Accuracy: 87.5%
# Accuracy: 93.75%
# Accuracy: 82.8125%
# Accuracy: 82.8125%
# Accuracy: 79.6875%
# Accuracy: 85.9375%
# Accuracy: 82.8125%
# Accuracy: 90.625%
# Accuracy: 84.375%
# Accuracy: 87.5%
# Accuracy: 89.0625%
# Accuracy: 84.375%
# Accuracy: 92.1875%
# Accuracy: 79.6875%
# Accuracy: 87.5%
# Accuracy: 81.25%
# Accuracy: 81.25%
# Accuracy: 87.5%
# Accuracy: 82.8125%
# Accuracy: 93.75%
# Accuracy: 92.1875%
# Accuracy: 85.9375%
# Accuracy: 84.375%
# Accuracy: 90.625%
# Accuracy: 84.375%
# Accuracy: 89.0625%
# Accuracy: 85.9375%
# Accuracy: 89.0625%
# Accuracy: 85.9375%
# Accuracy: 90.625%
# Accuracy: 82.8125%
# Accuracy: 87.5%
# Accuracy: 92.1875%
# Accuracy: 85.9375%
# Accuracy: 81.25%
# Accuracy: 85.9375%
# Accuracy: 84.375%
# Accuracy: 85.9375%
# Accuracy: 76.5625%
# Accuracy: 81.25%
# Accuracy: 90.625%
# Accuracy: 84.375%
# Accuracy: 84.375%
# Accuracy: 81.25%
# Accuracy: 87.5%
# Accuracy: 89.0625%
# Accuracy: 84.375%
# Accuracy: 90.625%
# Accuracy: 89.0625%
# Accuracy: 87.5%
# Accuracy: 82.8125%
# Accuracy: 73.4375%
# Accuracy: 92.1875%
# Accuracy: 87.5%
# Accuracy: 87.5%
# Accuracy: 87.5%
# Accuracy: 87.5%
# Accuracy: 82.8125%
# Accuracy: 85.9375%
# Accuracy: 82.8125%
# Accuracy: 79.6875%
# Accuracy: 81.25%
# Accuracy: 78.125%
# Accuracy: 84.375%
# Accuracy: 87.5%
# Accuracy: 82.8125%
# Accuracy: 90.625%
# Accuracy: 89.0625%
# Accuracy: 96.875%
# Accuracy: 85.9375%
# Accuracy: 85.9375%
# Accuracy: 85.9375%
# Accuracy: 85.9375%
# Accuracy: 85.9375%
# Accuracy: 85.9375%
# Accuracy: 89.0625%
# Accuracy: 79.6875%
# Accuracy: 89.0625%
# Accuracy: 85.9375%
# Accuracy: 78.125%
# Accuracy: 84.375%
# Accuracy: 82.8125%
# Accuracy: 90.625%
# Accuracy: 84.375%
# Accuracy: 87.5%
# Accuracy: 81.25%
# Accuracy: 87.5%
# Accuracy: 89.0625%
# Accuracy: 85.9375%
# Accuracy: 76.5625%
# Accuracy: 89.0625%
# Accuracy: 85.9375%
# Accuracy: 81.25%
# Accuracy: 85.9375%
# Accuracy: 89.0625%
# Accuracy: 90.625%
# Accuracy: 78.125%
# Accuracy: 89.0625%
# Accuracy: 90.625%
# Accuracy: 90.625%
# Accuracy: 85.9375%
# Accuracy: 79.6875%
# Accuracy: 82.8125%
# Accuracy: 87.5%
# Accuracy: 84.375%
# Accuracy: 84.375%
# Accuracy: 85.9375%
# Accuracy: 84.375%
# Accuracy: 92.1875%
# Accuracy: 78.125%
# Accuracy: 89.0625%
# Accuracy: 84.375%
# Accuracy: 79.6875%
# Accuracy: 79.6875%
# Accuracy: 90.625%
# Accuracy: 84.375%
# Accuracy: 90.625%
# Accuracy: 87.5%
# Accuracy: 87.5%
# Accuracy: 85.9375%
# Accuracy: 84.375%
# Accuracy: 92.1875%
# Accuracy: 85.9375%
# Accuracy: 90.625%
# Accuracy: 85.9375%
# Accuracy: 89.0625%
# Accuracy: 93.75%
# Accuracy: 85.9375%
# Accuracy: 81.25%
# Accuracy: 84.375%
# Accuracy: 84.375%
# Accuracy: 90.625%
# Accuracy: 92.1875%
# Accuracy: 79.6875%
# Accuracy: 85.9375%
# Accuracy: 89.0625%
# Accuracy: 81.25%
# Accuracy: 89.0625%
# Accuracy: 75.0%
# Accuracy: 87.5%
# Accuracy: 79.6875%
# Accuracy: 87.5%
# Accuracy: 84.375%
# Accuracy: 82.8125%
# Accuracy: 89.0625%
# Accuracy: 85.9375%
# Accuracy: 84.375%
# Accuracy: 81.25%
# Accuracy: 89.0625%
# Accuracy: 84.375%
# Accuracy: 82.8125%
# Accuracy: 87.5%
# Accuracy: 92.1875%
# Accuracy: 75.0%
# Accuracy: 87.5%
# Accuracy: 89.0625%
# Accuracy: 81.25%
# Accuracy: 84.375%
# Accuracy: 81.25%
# Accuracy: 85.9375%
# Accuracy: 89.0625%
# Accuracy: 89.0625%
# Accuracy: 85.9375%
# Accuracy: 85.9375%
# Accuracy: 85.9375%
# Accuracy: 89.0625%
# Accuracy: 93.75%
# Accuracy: 87.5%
# Accuracy: 90.625%
# Accuracy: 85.9375%
# Accuracy: 81.25%
# Accuracy: 81.25%
# Accuracy: 84.375%
# Accuracy: 89.0625%
# Accuracy: 92.1875%
# Accuracy: 95.3125%
# Accuracy: 75.0%
# Accuracy: 87.5%
# Accuracy: 87.5%
# Accuracy: 85.9375%
# Accuracy: 90.625%
# Accuracy: 92.1875%
# Accuracy: 85.9375%
# Accuracy: 78.125%
# Accuracy: 84.375%
# Accuracy: 76.5625%
# Accuracy: 90.625%
# Accuracy: 87.5%
# Accuracy: 85.9375%
# Accuracy: 76.5625%
# Accuracy: 85.9375%
# Accuracy: 75.0%
# Accuracy: 82.8125%
# Accuracy: 87.5%
# Accuracy: 87.5%
# Accuracy: 93.75%
# Accuracy: 92.1875%
# Accuracy: 85.9375%
# Accuracy: 82.8125%
# Accuracy: 84.375%
# Accuracy: 92.1875%
# Accuracy: 82.8125%
# Accuracy: 81.25%
# Accuracy: 84.375%
# Accuracy: 85.9375%
# Accuracy: 82.8125%
# Accuracy: 90.625%
# Accuracy: 89.0625%
# Accuracy: 92.1875%
# Accuracy: 75.0%
# Accuracy: 81.25%
# Accuracy: 89.0625%
# Accuracy: 89.0625%
# Accuracy: 87.5%
# Accuracy: 85.9375%
# Accuracy: 89.0625%
# Accuracy: 76.5625%
# Accuracy: 82.8125%
# Accuracy: 89.0625%
# Accuracy: 87.5%
# Accuracy: 90.625%
# Accuracy: 81.25%
# Accuracy: 87.5%
# Accuracy: 84.375%
# Accuracy: 93.75%
# Accuracy: 85.9375%
# Accuracy: 82.8125%
# Accuracy: 81.25%
# Accuracy: 87.5%
# Accuracy: 92.1875%
# Accuracy: 87.5%
# Accuracy: 85.9375%
# Accuracy: 87.5%
# Accuracy: 92.1875%
# Accuracy: 87.5%
# Accuracy: 82.8125%
# Accuracy: 85.9375%
# Accuracy: 92.1875%
# Accuracy: 89.0625%
# Accuracy: 92.1875%
# Accuracy: 84.375%
# Accuracy: 81.25%
# Accuracy: 87.5%
# Accuracy: 89.0625%
# Accuracy: 82.8125%
# Accuracy: 82.8125%
# Accuracy: 84.375%
# Accuracy: 84.375%
# Accuracy: 87.5%
# Accuracy: 93.75%
# Accuracy: 75.0%
# Accuracy: 84.375%
# Accuracy: 90.625%
# Accuracy: 79.6875%
# Accuracy: 79.6875%
# Accuracy: 92.1875%
# Accuracy: 84.375%
# Accuracy: 85.9375%
# Accuracy: 85.9375%
# Accuracy: 87.5%
# Accuracy: 84.375%
# Accuracy: 89.0625%
# Accuracy: 76.5625%
# Accuracy: 87.5%
# Accuracy: 82.8125%
# Accuracy: 92.1875%
# Accuracy: 82.8125%
# Accuracy: 90.625%
# Accuracy: 82.8125%
# Accuracy: 90.625%
# Accuracy: 78.125%
# Accuracy: 87.5%
# Accuracy: 82.8125%
# Accuracy: 85.9375%
# Accuracy: 76.5625%
# Accuracy: 87.5%
# Accuracy: 87.5%
# Accuracy: 85.9375%
# Accuracy: 90.625%
# Accuracy: 81.25%
# Accuracy: 82.8125%
# Accuracy: 85.9375%
# Accuracy: 73.4375%
# Accuracy: 90.625%
# Accuracy: 79.6875%
# Accuracy: 82.8125%
# Accuracy: 95.3125%
# Accuracy: 82.8125%
# Accuracy: 92.1875%
# Accuracy: 92.1875%
# Accuracy: 89.0625%
# Accuracy: 87.5%
# Accuracy: 81.25%
# Accuracy: 84.375%
# Accuracy: 87.5%
# Accuracy: 87.5%
# Accuracy: 92.1875%
# Accuracy: 75.0%
# Accuracy: 89.0625%
# Accuracy: 85.9375%
# Accuracy: 92.1875%
# Accuracy: 79.6875%
# Accuracy: 85.9375%
# Accuracy: 82.8125%
# Accuracy: 87.5%
# Accuracy: 75.0%
# Accuracy: 82.8125%
# Accuracy: 85.9375%
# Accuracy: 84.375%
# Accuracy: 90.625%
# Accuracy: 87.5%
# Accuracy: 89.0625%
# Accuracy: 81.25%
# Accuracy: 85.9375%
# Accuracy: 84.375%
# Accuracy: 87.5%
# Accuracy: 87.5%
# Accuracy: 81.25%
# Accuracy: 84.375%
# Accuracy: 85.9375%
# Accuracy: 84.375%
# Accuracy: 84.375%
# Accuracy: 87.5%
# Accuracy: 92.1875%
# Accuracy: 87.5%
# Accuracy: 76.5625%
# Accuracy: 84.375%
# Accuracy: 81.25%
# Accuracy: 87.5%
# Accuracy: 85.9375%
# Accuracy: 89.0625%
# Accuracy: 89.0625%
# Accuracy: 84.375%
# Accuracy: 100.0%
# Accuracy: 87.5%
# Accuracy: 85.9375%
# Accuracy: 87.5%
# Accuracy: 81.25%
# Accuracy: 84.375%
# Accuracy: 89.0625%
# Accuracy: 82.8125%
# Accuracy: 92.1875%
# Accuracy: 82.8125%
# Accuracy: 87.5%
# Accuracy: 90.625%
# Accuracy: 85.9375%
# Accuracy: 82.8125%
# Accuracy: 92.1875%
# Accuracy: 90.625%
# Accuracy: 87.5%
# Accuracy: 89.0625%
# Accuracy: 87.5%
# Accuracy: 85.9375%
# Accuracy: 82.8125%
# Accuracy: 89.0625%
# Accuracy: 78.125%
# Accuracy: 79.6875%
# Accuracy: 89.0625%
# Accuracy: 81.25%
# Accuracy: 89.0625%
# Accuracy: 84.375%
# Accuracy: 84.375%
# Accuracy: 89.0625%
# Accuracy: 89.0625%
# Accuracy: 87.5%
# Accuracy: 85.9375%
# Accuracy: 82.8125%
# Accuracy: 92.1875%
# Accuracy: 87.5%
# Accuracy: 92.1875%
# Accuracy: 84.375%
# Accuracy: 82.8125%
# Accuracy: 95.3125%
# Accuracy: 90.625%
# Accuracy: 75.0%
# Accuracy: 84.375%
# Accuracy: 84.375%
# Accuracy: 95.3125%
# Accuracy: 87.5%
# Accuracy: 85.9375%
# Accuracy: 89.0625%
# Accuracy: 84.375%
# Accuracy: 78.125%
# Accuracy: 85.9375%
# Accuracy: 89.0625%
# Accuracy: 96.875%
# Accuracy: 89.0625%
# Accuracy: 89.0625%
# Accuracy: 92.1875%
# Accuracy: 87.5%
# Accuracy: 82.8125%
# Accuracy: 90.625%
# Accuracy: 85.9375%
# Accuracy: 82.8125%
# Accuracy: 89.0625%
# Accuracy: 87.5%
# Accuracy: 84.375%
# Accuracy: 93.75%
# Accuracy: 84.375%
# Accuracy: 82.8125%
# Accuracy: 82.8125%
# Accuracy: 93.75%
# Accuracy: 89.0625%
# Accuracy: 82.8125%
# Accuracy: 89.0625%
# Accuracy: 85.9375%
# Accuracy: 90.625%
# Accuracy: 85.9375%
# Accuracy: 87.5%
# Accuracy: 84.375%
# Accuracy: 89.0625%
# Accuracy: 89.0625%
# Accuracy: 84.375%
# Accuracy: 81.25%
# Accuracy: 90.625%
# Accuracy: 84.375%
# Accuracy: 87.5%
# Accuracy: 90.625%
# Accuracy: 85.9375%
# Accuracy: 82.8125%
# Accuracy: 90.625%
# Accuracy: 85.9375%
# Accuracy: 84.375%
# Accuracy: 85.9375%
# Accuracy: 90.625%
# Accuracy: 87.5%
# Accuracy: 93.75%
# Accuracy: 85.9375%
# Accuracy: 89.0625%
# Accuracy: 84.375%
# Accuracy: 85.9375%
# Accuracy: 89.0625%
# Accuracy: 87.5%
# Accuracy: 90.625%
# Accuracy: 81.25%
# Accuracy: 89.0625%
# Accuracy: 92.1875%
# Accuracy: 87.5%
# Accuracy: 90.625%
# Accuracy: 82.8125%
# Accuracy: 87.5%
# Accuracy: 87.5%
# Accuracy: 90.625%
# Accuracy: 84.375%
# Accuracy: 78.125%
# Accuracy: 92.1875%
# Accuracy: 79.6875%
# Accuracy: 85.9375%
# Accuracy: 84.375%
# Accuracy: 89.0625%
# Accuracy: 87.5%
# Accuracy: 92.1875%
# Accuracy: 89.0625%
# Accuracy: 90.625%
# Accuracy: 89.0625%
# Accuracy: 89.0625%
# Accuracy: 90.625%
# Accuracy: 89.0625%
# Accuracy: 90.625%
# Accuracy: 87.5%
# Accuracy: 82.8125%
# Accuracy: 93.75%
# Accuracy: 81.25%
# Accuracy: 87.5%
# Accuracy: 82.8125%
# Accuracy: 92.1875%
# Accuracy: 76.5625%
# Accuracy: 93.75%
# Accuracy: 87.5%
# Accuracy: 89.0625%
# Accuracy: 76.5625%
# Accuracy: 92.1875%
# Accuracy: 87.5%
# Accuracy: 85.9375%
# Accuracy: 87.5%
# Accuracy: 89.0625%
# Accuracy: 82.8125%
# Accuracy: 87.5%
# Accuracy: 87.5%
# Accuracy: 87.5%
# Accuracy: 90.625%
# Accuracy: 84.375%
# Accuracy: 79.6875%
# Accuracy: 95.3125%
# Accuracy: 85.9375%
# Accuracy: 78.125%
# Accuracy: 90.625%
# Accuracy: 89.0625%
# Accuracy: 95.3125%
# Accuracy: 82.8125%
# Accuracy: 87.5%
# Accuracy: 89.0625%
# Accuracy: 73.4375%
# Accuracy: 92.1875%
# Accuracy: 89.0625%
# Accuracy: 85.9375%
# Accuracy: 85.9375%
# Accuracy: 82.8125%
# Accuracy: 87.5%
# Accuracy: 78.125%
# Accuracy: 82.8125%
# Accuracy: 81.25%
# Accuracy: 90.625%
# Accuracy: 82.8125%
# Accuracy: 76.5625%
# Accuracy: 85.9375%
# Accuracy: 81.25%
# Accuracy: 95.3125%
# Accuracy: 95.3125%
# Accuracy: 85.9375%
# Accuracy: 81.25%
# Accuracy: 85.9375%
# Accuracy: 90.625%
# Accuracy: 85.9375%
# Accuracy: 84.375%
# Accuracy: 87.5%
# Accuracy: 90.625%
# Accuracy: 79.6875%
# Accuracy: 82.8125%
# Accuracy: 84.375%
# Accuracy: 89.0625%
# Accuracy: 87.5%
# Accuracy: 82.8125%
# Accuracy: 89.0625%
# Accuracy: 76.5625%
# Accuracy: 93.75%
# Accuracy: 89.0625%
# Accuracy: 85.9375%
# Accuracy: 90.625%
# Accuracy: 92.1875%
# Accuracy: 81.25%
# Accuracy: 92.1875%
# Accuracy: 87.5%
# Accuracy: 95.3125%
# Accuracy: 84.375%
# Accuracy: 87.5%
# Accuracy: 85.9375%
# Accuracy: 85.9375%
# Accuracy: 87.5%
# Accuracy: 89.0625%
# Accuracy: 85.9375%
# Accuracy: 90.625%
# Accuracy: 87.5%
# Accuracy: 84.375%
# Accuracy: 89.0625%
# Accuracy: 78.125%
# Accuracy: 90.625%
# Accuracy: 87.5%
# Accuracy: 92.1875%
# Accuracy: 79.6875%
# Accuracy: 95.3125%
# Accuracy: 84.375%
# Accuracy: 87.5%
# Accuracy: 85.9375%
# Accuracy: 85.9375%
# Accuracy: 87.5%
# Accuracy: 90.625%
# Accuracy: 76.5625%
# Accuracy: 89.0625%
# Accuracy: 92.1875%
# Accuracy: 87.5%
# Accuracy: 89.0625%
# Accuracy: 79.6875%
# Accuracy: 92.1875%
# Accuracy: 87.5%
# Accuracy: 92.1875%
# Accuracy: 87.5%
# Accuracy: 87.5%
# Accuracy: 87.5%
# Accuracy: 84.375%
# Accuracy: 87.5%
# Accuracy: 81.25%
# Accuracy: 78.125%
# Accuracy: 90.625%
# Accuracy: 92.1875%
# Accuracy: 81.25%
# Accuracy: 90.625%
# Accuracy: 98.4375%
# Accuracy: 93.75%
# Accuracy: 84.375%
# Accuracy: 89.0625%
# Accuracy: 84.375%
# Accuracy: 90.625%
# Accuracy: 92.1875%
# Accuracy: 90.625%
# Accuracy: 89.0625%
# Accuracy: 89.0625%
# Accuracy: 89.0625%
# Accuracy: 84.375%
# Accuracy: 90.625%
# Accuracy: 87.5%
# Accuracy: 85.9375%
# Accuracy: 84.375%
# Accuracy: 85.9375%
# Accuracy: 90.625%
# Accuracy: 87.5%
# Accuracy: 95.3125%
# Accuracy: 89.0625%
# Accuracy: 81.25%
# Accuracy: 82.8125%
# Accuracy: 87.5%
# Accuracy: 84.375%
# Accuracy: 85.9375%
# Accuracy: 90.625%
# Accuracy: 79.6875%
# Accuracy: 81.25%
# Accuracy: 89.0625%
# Accuracy: 84.375%
# Accuracy: 89.0625%
# Accuracy: 90.625%
# Accuracy: 85.9375%
# Accuracy: 82.8125%
# Accuracy: 82.8125%
# Accuracy: 89.0625%
# Accuracy: 79.6875%
# Accuracy: 84.375%
# Accuracy: 85.9375%
# Accuracy: 92.1875%
# Accuracy: 89.0625%
# Accuracy: 90.625%
# Accuracy: 84.375%
# Accuracy: 90.625%
# Accuracy: 85.9375%
# Accuracy: 87.5%
# Accuracy: 87.5%
# Accuracy: 79.6875%
# Accuracy: 89.0625%
# Accuracy: 82.8125%
# Accuracy: 87.5%
# Accuracy: 82.8125%
# Accuracy: 85.9375%
# Accuracy: 89.0625%
# Accuracy: 82.8125%
# Accuracy: 84.375%
# Accuracy: 90.625%
# Accuracy: 92.1875%
# Accuracy: 81.25%
# Accuracy: 89.0625%
# Accuracy: 85.9375%
# Accuracy: 81.25%
# Accuracy: 92.1875%
# Accuracy: 92.1875%
# Accuracy: 93.75%
# Accuracy: 93.75%
# Accuracy: 81.25%
# Accuracy: 87.5%
# Accuracy: 85.9375%
# Accuracy: 93.75%
# Accuracy: 85.9375%
# Accuracy: 81.25%
# Accuracy: 81.25%
# Accuracy: 84.375%
# Accuracy: 89.0625%
# Accuracy: 93.75%
# Accuracy: 85.9375%
# Accuracy: 76.5625%
# Accuracy: 95.3125%
# Accuracy: 82.8125%
# Accuracy: 89.0625%
# Accuracy: 85.9375%
# Accuracy: 89.0625%
# Accuracy: 81.25%
# Accuracy: 81.25%
# Accuracy: 87.5%
# Accuracy: 87.5%
# Accuracy: 87.5%
# Accuracy: 87.5%
# Accuracy: 93.75%
# Accuracy: 82.8125%
# Accuracy: 95.3125%
# Accuracy: 85.9375%
# Accuracy: 87.5%
# Accuracy: 84.375%
# Accuracy: 90.625%
# Accuracy: 87.5%
# Accuracy: 84.375%
# Accuracy: 87.5%
# Accuracy: 89.0625%
# Accuracy: 87.5%
# Accuracy: 84.375%
# Accuracy: 84.375%
# Accuracy: 85.9375%
# Accuracy: 87.5%
# Accuracy: 89.0625%
# Accuracy: 82.8125%
# Accuracy: 82.8125%
# Accuracy: 89.0625%
# Accuracy: 85.9375%
# Accuracy: 92.1875%
# Accuracy: 92.1875%
# Accuracy: 85.9375%
# Accuracy: 87.5%
# Accuracy: 81.25%
# Accuracy: 82.8125%
# Accuracy: 85.9375%
# Accuracy: 93.75%
# Accuracy: 85.9375%
# Accuracy: 90.625%
# Accuracy: 87.5%
# Accuracy: 90.625%
# Accuracy: 93.75%
# Accuracy: 90.625%
# Accuracy: 89.0625%
# Accuracy: 85.9375%
# Accuracy: 79.6875%
# Accuracy: 95.3125%
# Accuracy: 89.0625%
# Accuracy: 84.375%
# Accuracy: 78.125%
# Accuracy: 85.9375%
# Accuracy: 92.1875%
# Accuracy: 82.8125%
# Accuracy: 87.5%
# Accuracy: 89.0625%
# Accuracy: 85.9375%
# Accuracy: 87.5%
# Accuracy: 90.625%
# Accuracy: 84.375%
# Accuracy: 82.8125%
# Accuracy: 85.9375%
# Accuracy: 79.6875%
# Accuracy: 85.9375%
# Accuracy: 89.0625%
# Accuracy: 90.625%
# Accuracy: 89.0625%
# Accuracy: 93.75%
# Accuracy: 84.375%
# Accuracy: 90.625%
# Accuracy: 85.9375%
# Accuracy: 87.5%
# Accuracy: 87.5%
# Accuracy: 84.375%
# Accuracy: 89.0625%
# Accuracy: 87.5%
# Accuracy: 82.8125%
# Accuracy: 90.625%
# Accuracy: 82.8125%
# Accuracy: 93.75%
# Accuracy: 89.0625%
# Accuracy: 81.25%
# Accuracy: 81.25%
# Accuracy: 85.9375%
# Accuracy: 85.9375%
# Accuracy: 85.9375%
# Accuracy: 85.9375%
# Accuracy: 89.0625%
# Accuracy: 81.25%
# Accuracy: 92.1875%
# Accuracy: 85.9375%
# Accuracy: 84.375%
# Accuracy: 78.125%
# Accuracy: 85.9375%
# Accuracy: 76.5625%
# Accuracy: 92.1875%
# Accuracy: 87.5%
# Accuracy: 76.5625%
# Accuracy: 82.8125%
# Accuracy: 82.8125%
# Accuracy: 89.0625%
# Accuracy: 82.8125%
# Accuracy: 82.8125%
# Accuracy: 90.625%
# Accuracy: 93.75%
# Accuracy: 79.6875%
# Accuracy: 82.8125%
# Accuracy: 85.9375%
# Accuracy: 87.5%
# Accuracy: 85.9375%
# Accuracy: 85.9375%
# Accuracy: 84.375%
# Accuracy: 87.5%
# Accuracy: 84.375%
# Accuracy: 81.25%
# Accuracy: 87.5%
# Accuracy: 81.25%
# Accuracy: 87.5%
# Accuracy: 87.5%
# Accuracy: 89.0625%
# Accuracy: 90.625%
# Accuracy: 82.8125%
# Accuracy: 85.9375%
# Accuracy: 85.9375%
# Accuracy: 85.9375%
# Accuracy: 89.0625%
# Accuracy: 87.5%
# Accuracy: 79.6875%
# Accuracy: 82.8125%
# Accuracy: 76.5625%
# Accuracy: 93.75%
# Accuracy: 85.9375%
# Accuracy: 89.0625%
# Accuracy: 75.0%
# Accuracy: 89.0625%
# Accuracy: 84.375%
# Accuracy: 90.625%
# Accuracy: 84.375%
# Accuracy: 76.5625%
# Accuracy: 87.5%
# Accuracy: 79.6875%
# Accuracy: 78.125%
# Accuracy: 85.9375%
# Accuracy: 89.0625%
# Accuracy: 79.6875%
# Accuracy: 85.9375%
# Accuracy: 87.5%
# Accuracy: 89.0625%
# Accuracy: 85.9375%
# Accuracy: 87.5%
# Accuracy: 85.9375%
# Accuracy: 89.0625%
# Accuracy: 85.9375%
# Accuracy: 87.5%
# Accuracy: 81.25%
# Accuracy: 85.9375%
# Accuracy: 81.25%
# Accuracy: 89.0625%
# Accuracy: 87.5%
# Accuracy: 84.375%
# Accuracy: 89.0625%
# Accuracy: 85.9375%
# Accuracy: 85.9375%
# Accuracy: 78.125%
# Accuracy: 87.5%
# Accuracy: 87.5%
# Accuracy: 89.0625%
# Accuracy: 84.375%
# Accuracy: 87.5%
# Accuracy: 76.5625%
# Accuracy: 89.0625%
# Accuracy: 90.625%
# Accuracy: 87.5%
# Accuracy: 85.9375%
# Accuracy: 85.9375%
# Accuracy: 89.0625%
# Accuracy: 81.25%
# Accuracy: 93.75%
# Accuracy: 89.0625%
# Accuracy: 85.9375%
# Accuracy: 81.25%
# Accuracy: 82.8125%
# Accuracy: 87.5%
# Accuracy: 92.1875%
# Accuracy: 85.9375%
# Accuracy: 90.625%
# Accuracy: 82.8125%
# Accuracy: 82.8125%
# Accuracy: 84.375%
# Accuracy: 89.0625%
# Accuracy: 84.375%
# Accuracy: 81.25%
# Accuracy: 92.1875%
# Accuracy: 92.1875%
# Accuracy: 85.9375%
# Accuracy: 92.1875%
# Accuracy: 92.1875%
# Accuracy: 92.1875%
# Accuracy: 82.8125%
# Accuracy: 92.1875%
# Accuracy: 92.1875%
# Accuracy: 84.375%
# Accuracy: 87.5%
# Accuracy: 84.375%
# Accuracy: 82.8125%
# Accuracy: 87.5%
# Accuracy: 81.25%
# Accuracy: 87.5%
# Accuracy: 89.0625%
# Accuracy: 93.75%
# Accuracy: 84.375%
# Accuracy: 85.9375%
# Accuracy: 95.3125%
# Accuracy: 84.375%
# Accuracy: 85.9375%
# Accuracy: 87.5%
# Accuracy: 85.9375%
# Accuracy: 85.9375%
# Accuracy: 92.1875%
# Accuracy: 85.9375%
# Accuracy: 90.625%
# Accuracy: 85.9375%
# Accuracy: 90.625%
# Accuracy: 85.9375%
# Accuracy: 85.9375%
# Accuracy: 89.0625%
# Accuracy: 84.375%
# Accuracy: 85.9375%
# Accuracy: 82.8125%
# Accuracy: 89.0625%
# Accuracy: 82.8125%
# Accuracy: 82.8125%
# Accuracy: 84.375%
# Accuracy: 87.5%
# Accuracy: 85.9375%
# Accuracy: 85.9375%
# Accuracy: 89.0625%
# Accuracy: 89.0625%
# Accuracy: 81.25%
# Accuracy: 89.0625%
# Accuracy: 87.5%
# Accuracy: 79.6875%
# Accuracy: 84.375%
# Accuracy: 82.8125%
# Accuracy: 89.0625%
# Accuracy: 90.625%
# Accuracy: 90.625%
# Accuracy: 87.5%
# Accuracy: 87.5%
# Accuracy: 84.375%
# Accuracy: 90.625%
# Accuracy: 90.625%
# Accuracy: 89.0625%
# Accuracy: 87.5%
# Accuracy: 82.8125%
# Accuracy: 87.5%
# Accuracy: 89.0625%
# Accuracy: 89.0625%
# Accuracy: 84.375%
# Accuracy: 85.9375%
# Accuracy: 85.9375%
# Accuracy: 85.9375%
# Accuracy: 85.9375%
# Accuracy: 82.8125%
# Accuracy: 90.625%
# Accuracy: 85.9375%
# Accuracy: 87.5%
# Accuracy: 89.0625%
# Accuracy: 89.0625%
# Accuracy: 89.0625%
# Accuracy: 85.9375%
# Accuracy: 90.625%
# Accuracy: 84.375%
# Accuracy: 82.8125%
# Accuracy: 84.375%
# Accuracy: 90.625%
# Accuracy: 92.1875%
# Accuracy: 89.0625%
# Accuracy: 84.375%
# Accuracy: 85.9375%
# Accuracy: 81.25%
# Accuracy: 89.0625%
# Accuracy: 82.8125%
# Accuracy: 87.5%
# Accuracy: 85.9375%
# Accuracy: 82.8125%
# Accuracy: 79.6875%
# Accuracy: 92.1875%
# Accuracy: 95.3125%
# Accuracy: 87.5%
# Accuracy: 92.1875%
# Accuracy: 85.9375%
# Accuracy: 87.5%
# Accuracy: 75.0%
# Accuracy: 85.9375%
# Accuracy: 89.0625%
# Accuracy: 79.6875%
# Accuracy: 90.625%
# Accuracy: 93.75%
# Accuracy: 87.5%
# Accuracy: 81.25%
# Accuracy: 89.0625%
# Accuracy: 81.25%
# Accuracy: 93.75%
# Accuracy: 87.5%
# Accuracy: 92.1875%
# Accuracy: 89.0625%
# Accuracy: 82.8125%
# Accuracy: 90.625%
# Accuracy: 87.5%
# Accuracy: 87.5%
# Accuracy: 90.625%
# Accuracy: 75.0%
# Accuracy: 84.375%
# Accuracy: 90.625%
# Accuracy: 95.3125%
# Accuracy: 89.0625%
# Accuracy: 90.625%
# Accuracy: 87.5%
# Accuracy: 84.375%
# Accuracy: 85.9375%
# Accuracy: 93.75%
# Accuracy: 87.5%
# Accuracy: 92.1875%
# Accuracy: 87.5%
# Accuracy: 87.5%
# Accuracy: 96.875%
# Accuracy: 84.375%
# Accuracy: 81.25%
# Accuracy: 95.3125%
# Accuracy: 85.9375%
# Accuracy: 93.75%
# Accuracy: 89.0625%
# Accuracy: 89.0625%
# Accuracy: 85.9375%
# Accuracy: 90.625%
# Accuracy: 89.0625%
# Accuracy: 90.625%
# Accuracy: 95.3125%
# Accuracy: 81.25%
# Accuracy: 87.5%
# Accuracy: 95.3125%
# Accuracy: 87.5%
# Accuracy: 85.9375%
# Accuracy: 89.0625%
# Accuracy: 92.1875%
# Accuracy: 89.0625%
# Accuracy: 85.9375%
# Accuracy: 87.5%
# Accuracy: 89.0625%
# Accuracy: 84.375%
# Accuracy: 90.625%
# Accuracy: 87.5%
# Accuracy: 87.5%
# Accuracy: 87.5%
# Accuracy: 84.375%
# Accuracy: 84.375%
# Accuracy: 90.625%
# Accuracy: 84.375%
# Accuracy: 78.125%
# Accuracy: 82.8125%
# Accuracy: 82.8125%
# Accuracy: 89.0625%
# Accuracy: 90.625%
# Accuracy: 81.25%
# Accuracy: 89.0625%
# Accuracy: 87.5%
# Accuracy: 87.5%
# Accuracy: 90.625%
# Accuracy: 93.75%
# Accuracy: 85.9375%
# Accuracy: 85.9375%
# Accuracy: 87.5%
# Accuracy: 78.125%
# Accuracy: 90.625%
# Accuracy: 87.5%
# Accuracy: 92.1875%
# Accuracy: 84.375%
# Accuracy: 90.625%
# Accuracy: 87.5%
# Accuracy: 81.25%
# Accuracy: 87.5%
# Accuracy: 87.5%
# Accuracy: 82.8125%
# Accuracy: 89.0625%
# Accuracy: 84.375%
# Accuracy: 89.0625%
# Accuracy: 92.1875%
# Accuracy: 90.625%
# Accuracy: 93.75%
# Accuracy: 85.9375%
# Accuracy: 90.625%
# Accuracy: 87.5%
# Accuracy: 85.9375%
# Accuracy: 84.375%
# Accuracy: 93.75%
# Accuracy: 93.75%
# Accuracy: 89.0625%
# Accuracy: 89.0625%
# Accuracy: 87.5%
# Accuracy: 93.75%
# Accuracy: 92.1875%
# Accuracy: 93.75%
# Accuracy: 95.3125%
# Accuracy: 85.9375%
# Accuracy: 76.5625%
# Accuracy: 84.375%
# Accuracy: 82.8125%
# Accuracy: 81.25%
# Accuracy: 93.75%
# Accuracy: 90.625%
# Accuracy: 93.75%
# Accuracy: 92.1875%
# Accuracy: 87.5%
# Accuracy: 79.6875%
# Accuracy: 92.1875%
# Accuracy: 85.9375%
# Accuracy: 90.625%
# Accuracy: 85.9375%
# Accuracy: 92.1875%
# Accuracy: 89.0625%
# Accuracy: 84.375%
# Accuracy: 84.375%
# Accuracy: 87.5%
# Accuracy: 87.5%
# Accuracy: 90.625%
# Accuracy: 84.375%
# Accuracy: 82.8125%
# Accuracy: 93.75%
# Accuracy: 92.1875%
# Accuracy: 87.5%
# Accuracy: 84.375%
# Accuracy: 89.0625%
# Accuracy: 85.9375%
# Accuracy: 87.5%
# Accuracy: 89.0625%
# Accuracy: 84.375%
# Accuracy: 78.125%
# Accuracy: 82.8125%
# Accuracy: 90.625%
# Accuracy: 89.0625%
# Accuracy: 90.625%
# Accuracy: 82.8125%
# Accuracy: 89.0625%
# Accuracy: 90.625%
# Accuracy: 92.1875%
# Accuracy: 89.0625%
# Accuracy: 85.9375%
# Accuracy: 85.9375%
# Accuracy: 85.9375%
# Accuracy: 81.25%
# Accuracy: 90.625%
# Accuracy: 84.375%
# Accuracy: 85.9375%
# Accuracy: 87.5%
# Accuracy: 85.9375%
# Accuracy: 89.0625%
# Accuracy: 89.0625%
# Accuracy: 90.625%
# Accuracy: 87.5%
# Accuracy: 93.75%
# Accuracy: 87.5%
# Accuracy: 85.9375%
# Accuracy: 85.9375%
# Accuracy: 89.0625%
# Accuracy: 79.6875%
# Accuracy: 85.9375%
# Accuracy: 84.375%
# Accuracy: 87.5%
# Accuracy: 93.75%
# Accuracy: 95.3125%
# Accuracy: 84.375%
# Accuracy: 82.8125%
# Accuracy: 92.1875%
# Accuracy: 89.0625%
# Accuracy: 89.0625%
# Accuracy: 89.0625%
# Accuracy: 90.625%
# Accuracy: 81.25%
# Accuracy: 81.25%
# Accuracy: 87.5%
# Accuracy: 84.375%
# Accuracy: 87.5%
# Accuracy: 87.5%
# Accuracy: 87.5%
# Accuracy: 90.625%
# Accuracy: 85.9375%
# Accuracy: 89.0625%
# Accuracy: 85.9375%
# Accuracy: 87.5%
# Accuracy: 84.375%
# Accuracy: 84.375%
# Accuracy: 87.5%
# Accuracy: 89.0625%
# Accuracy: 90.625%
# Accuracy: 84.375%
# Accuracy: 85.9375%
# Accuracy: 84.375%
# Accuracy: 89.0625%
# Accuracy: 87.5%
# Accuracy: 89.0625%
# Accuracy: 82.8125%
# Accuracy: 82.8125%
# Accuracy: 89.0625%
# Accuracy: 89.0625%
# Accuracy: 92.1875%
# Accuracy: 93.75%
# Accuracy: 87.5%
# Accuracy: 90.625%
# Accuracy: 85.9375%
# Accuracy: 92.1875%
# Accuracy: 92.1875%
# Accuracy: 89.0625%
# Accuracy: 92.1875%
# Accuracy: 90.625%
# Accuracy: 89.0625%
# Accuracy: 84.375%
# Accuracy: 90.625%
# Accuracy: 87.5%
# Accuracy: 90.625%
# Accuracy: 82.8125%
# Accuracy: 87.5%
# Accuracy: 82.8125%
# Accuracy: 85.9375%
# Accuracy: 90.625%
# Accuracy: 82.8125%
# Accuracy: 90.625%
# Accuracy: 90.625%
# Accuracy: 89.0625%
# Accuracy: 84.375%
# Accuracy: 82.8125%
# Accuracy: 84.375%
# Accuracy: 87.5%
# Accuracy: 87.5%
# Accuracy: 84.375%
# Accuracy: 82.8125%
# Accuracy: 92.1875%
# Accuracy: 93.75%
# Accuracy: 90.625%
# Accuracy: 95.3125%
# Accuracy: 89.0625%
# Accuracy: 82.8125%
# Accuracy: 85.9375%
# Accuracy: 85.9375%
# Accuracy: 90.625%
# Accuracy: 84.375%
# Accuracy: 93.75%
# Accuracy: 90.625%
# Accuracy: 84.375%
# Accuracy: 90.625%
# Accuracy: 87.5%
# Accuracy: 90.625%
# Accuracy: 84.375%
# Accuracy: 90.625%
# Accuracy: 78.125%
# Accuracy: 93.75%
# Accuracy: 84.375%
# Accuracy: 87.5%
# Accuracy: 79.6875%
# Accuracy: 96.875%
# Accuracy: 92.1875%
# Accuracy: 85.9375%
# Accuracy: 85.9375%
# Accuracy: 82.8125%
# Accuracy: 95.3125%
# Accuracy: 84.375%
# Accuracy: 87.5%
# Accuracy: 79.6875%
# Accuracy: 87.5%
# Accuracy: 87.5%
# Accuracy: 84.375%
# Accuracy: 92.1875%
# Accuracy: 89.0625%
# Accuracy: 93.75%
# Accuracy: 89.0625%
# Accuracy: 96.875%
# Accuracy: 87.5%
# Accuracy: 93.75%
# Accuracy: 90.625%
# Accuracy: 87.5%
# Accuracy: 95.3125%
# Accuracy: 81.25%
# Accuracy: 85.9375%
# Accuracy: 84.375%
# Accuracy: 90.625%
# Accuracy: 82.8125%
# Accuracy: 90.625%
# Accuracy: 87.5%
# Accuracy: 92.1875%
# Accuracy: 89.0625%
# Accuracy: 92.1875%
# Accuracy: 89.0625%
# Accuracy: 96.875%
# Accuracy: 87.5%
# Accuracy: 87.5%
# Accuracy: 84.375%
# Accuracy: 89.0625%
# Accuracy: 84.375%
# Accuracy: 92.1875%
# Accuracy: 90.625%
# Accuracy: 90.625%
# Accuracy: 82.8125%
# Accuracy: 95.3125%
# Accuracy: 89.0625%
# Accuracy: 84.375%
# Accuracy: 85.9375%
# Accuracy: 79.6875%
# Accuracy: 87.5%
# Accuracy: 87.5%
# Accuracy: 92.1875%
# Accuracy: 89.0625%
# Accuracy: 85.9375%
# Accuracy: 85.9375%
# Accuracy: 89.0625%
# Accuracy: 87.5%
# Accuracy: 84.375%
# Accuracy: 87.5%
# Accuracy: 75.0%
# Accuracy: 87.5%
# Accuracy: 82.8125%
# Accuracy: 92.1875%
# Accuracy: 87.5%
# Accuracy: 87.5%
# Accuracy: 95.3125%
# Accuracy: 92.1875%
# Accuracy: 90.625%
# Accuracy: 90.625%
# Accuracy: 85.9375%
# Accuracy: 90.625%
# Accuracy: 79.6875%
# Accuracy: 89.0625%
# Accuracy: 82.8125%
# Accuracy: 87.5%
# Accuracy: 90.625%
# Accuracy: 84.375%
# Accuracy: 84.375%
# Accuracy: 89.0625%
# Accuracy: 87.5%
# Accuracy: 95.3125%
# Accuracy: 87.5%
# Accuracy: 85.9375%
# Accuracy: 95.3125%
# Accuracy: 87.5%
# Accuracy: 87.5%
# Accuracy: 84.375%
# Accuracy: 85.9375%
# Accuracy: 90.625%
# Accuracy: 92.1875%
# Accuracy: 76.5625%
# Accuracy: 84.375%
# Accuracy: 92.1875%
# Accuracy: 81.25%
# Accuracy: 76.5625%
# Accuracy: 89.0625%
# Accuracy: 82.8125%
# Accuracy: 87.5%
# Accuracy: 84.375%
# Accuracy: 87.5%
# Accuracy: 85.9375%
# Accuracy: 87.5%
# Accuracy: 89.0625%
# Accuracy: 93.75%
# Accuracy: 90.625%
# Accuracy: 84.375%
# Accuracy: 92.1875%
# Accuracy: 84.375%
# Accuracy: 82.8125%
# Accuracy: 84.375%
# Accuracy: 89.0625%
# Accuracy: 82.8125%
# Accuracy: 82.8125%
# Accuracy: 89.0625%
# Accuracy: 84.375%
# Accuracy: 78.125%
# Accuracy: 89.0625%
# Accuracy: 93.75%
# Accuracy: 85.9375%
# Accuracy: 82.8125%
# Accuracy: 93.75%
# Accuracy: 92.1875%
# Accuracy: 87.5%
# Accuracy: 85.9375%
# Accuracy: 87.5%
# Accuracy: 82.8125%
# Accuracy: 84.375%
# Accuracy: 85.9375%
# Accuracy: 84.375%
# Accuracy: 82.8125%
# Accuracy: 90.625%
# Accuracy: 93.75%
# Accuracy: 81.25%
# Accuracy: 85.9375%
# Accuracy: 92.1875%
# Accuracy: 95.3125%
# Accuracy: 89.0625%
# Accuracy: 89.0625%
# Accuracy: 85.9375%
# Accuracy: 85.9375%
# Accuracy: 87.5%
# Accuracy: 85.9375%
# Accuracy: 87.5%
# Accuracy: 87.5%
# Accuracy: 79.6875%
# Accuracy: 81.25%
# Accuracy: 82.8125%
# Accuracy: 85.9375%
# Accuracy: 92.1875%
# Accuracy: 90.625%
# Accuracy: 89.0625%
# Accuracy: 90.625%
# Accuracy: 84.375%
# Accuracy: 89.0625%
# Accuracy: 84.375%
# Accuracy: 89.0625%
# Accuracy: 93.75%
# Accuracy: 79.6875%
# Accuracy: 98.4375%
# Accuracy: 87.5%
# Accuracy: 95.3125%
# Accuracy: 85.9375%
# Accuracy: 87.5%
# Accuracy: 85.9375%
# Accuracy: 93.75%
# Accuracy: 84.375%
# Accuracy: 85.9375%
# Accuracy: 85.9375%
# Accuracy: 90.625%
# Accuracy: 96.875%
# Accuracy: 87.5%
# Accuracy: 85.9375%
# Accuracy: 84.375%
# Accuracy: 85.9375%
# Accuracy: 79.6875%
# Accuracy: 85.9375%
# Accuracy: 87.5%
# Accuracy: 95.3125%
# Accuracy: 87.5%
# Accuracy: 90.625%
# Accuracy: 85.9375%
# Accuracy: 87.5%
# Accuracy: 79.6875%
# Accuracy: 92.1875%
# Accuracy: 85.9375%
# Accuracy: 92.1875%
# Accuracy: 90.625%
# Accuracy: 87.5%
# Accuracy: 87.5%
# Accuracy: 82.8125%
# Accuracy: 92.1875%
# Accuracy: 89.0625%
# Accuracy: 96.875%
# Accuracy: 87.5%
# Accuracy: 96.875%
# Accuracy: 95.3125%
# Accuracy: 81.25%
# Accuracy: 85.9375%
# Accuracy: 82.8125%
# Accuracy: 85.9375%
# Accuracy: 93.75%
# Accuracy: 90.625%
# Accuracy: 92.1875%
# Accuracy: 90.625%
# Accuracy: 89.0625%
# Accuracy: 90.625%
# Accuracy: 95.3125%
# Accuracy: 84.375%
# Accuracy: 85.9375%
# Accuracy: 93.75%
# Accuracy: 84.375%
# Accuracy: 87.5%
# Accuracy: 85.9375%
# Accuracy: 85.9375%
# Accuracy: 89.0625%
# Accuracy: 82.8125%
# Accuracy: 93.75%
# Accuracy: 84.375%
# Accuracy: 82.8125%
# Accuracy: 84.375%
# Accuracy: 89.0625%
# Accuracy: 87.5%
# Accuracy: 84.375%
# Accuracy: 87.5%
# Accuracy: 93.75%
# Accuracy: 95.3125%
# Accuracy: 85.9375%
# Accuracy: 82.8125%
# Accuracy: 89.0625%
# Accuracy: 84.375%
# Accuracy: 87.5%
# Accuracy: 85.9375%
# Accuracy: 84.375%
# Accuracy: 84.375%
# Accuracy: 84.375%
# Accuracy: 92.1875%
# Accuracy: 90.625%
# Accuracy: 87.5%
# Accuracy: 89.0625%
# Accuracy: 92.1875%
# Accuracy: 87.5%
# Accuracy: 90.625%
# Accuracy: 87.5%
# Accuracy: 81.25%
# Accuracy: 81.25%
# Accuracy: 85.9375%
# Accuracy: 84.375%
# Accuracy: 90.625%
# Accuracy: 76.5625%
# Accuracy: 92.1875%
# Accuracy: 81.25%
# Accuracy: 89.0625%
# Accuracy: 85.9375%
# Accuracy: 82.8125%
# Accuracy: 87.5%
# Accuracy: 92.1875%
# Accuracy: 84.375%
# Accuracy: 85.9375%
# Accuracy: 85.9375%
# Accuracy: 93.75%
# Accuracy: 89.0625%
# Accuracy: 81.25%
# Accuracy: 76.5625%
# Accuracy: 90.625%
# Accuracy: 89.0625%
# Accuracy: 82.8125%
# Accuracy: 90.625%
# Accuracy: 87.5%
# Accuracy: 92.1875%
# Accuracy: 92.1875%
# Accuracy: 84.375%
# Accuracy: 84.375%
# Accuracy: 85.9375%
# Accuracy: 89.0625%
# Accuracy: 87.5%
# Accuracy: 81.25%
# Accuracy: 79.6875%
# Accuracy: 87.5%
# Accuracy: 87.5%
# Accuracy: 85.9375%
# Accuracy: 81.25%
# Accuracy: 87.5%
# Accuracy: 79.6875%
# Accuracy: 79.6875%
# Accuracy: 90.625%
# Accuracy: 89.0625%
# Accuracy: 89.0625%
# Accuracy: 92.1875%
# Accuracy: 82.8125%
# Accuracy: 87.5%
# Accuracy: 81.25%
# Accuracy: 85.9375%
# Accuracy: 84.375%
# Accuracy: 90.625%
# Accuracy: 92.1875%
# Accuracy: 90.625%
# Accuracy: 90.625%
# Accuracy: 85.9375%
# Accuracy: 89.0625%
# Accuracy: 89.0625%
# Accuracy: 89.0625%
# Accuracy: 76.5625%
# Accuracy: 76.5625%
# Accuracy: 82.8125%
# Accuracy: 90.625%
# Accuracy: 85.9375%
# Accuracy: 87.5%
# Accuracy: 92.1875%
# Accuracy: 84.375%
# Accuracy: 85.9375%
# Accuracy: 90.625%
# Accuracy: 84.375%
# Accuracy: 85.9375%
# Accuracy: 85.9375%
# Accuracy: 87.5%
# Accuracy: 84.375%
# Accuracy: 92.1875%
# Accuracy: 85.9375%
# Accuracy: 85.9375%
# Accuracy: 84.375%
# Accuracy: 93.75%
# Accuracy: 85.9375%
# Accuracy: 84.375%
# Accuracy: 90.625%
# Accuracy: 82.8125%
# Accuracy: 90.625%
# Accuracy: 90.625%
# Accuracy: 89.0625%
# Accuracy: 85.9375%
# Accuracy: 89.0625%
# Accuracy: 84.375%
# Accuracy: 90.625%
# Accuracy: 90.625%
# Accuracy: 81.25%
# Accuracy: 95.3125%
# Accuracy: 93.75%
# Accuracy: 87.5%
# Accuracy: 87.5%
# Accuracy: 85.9375%
# Accuracy: 87.5%
# Accuracy: 90.625%
# Accuracy: 84.375%
# Accuracy: 85.9375%
# Accuracy: 95.3125%
# Accuracy: 87.5%
# Accuracy: 92.1875%
# Accuracy: 82.8125%
# Accuracy: 90.625%
# Accuracy: 92.1875%
# Accuracy: 85.9375%
# Accuracy: 82.8125%
# Accuracy: 87.5%
# Accuracy: 90.625%
# Accuracy: 76.5625%
# Accuracy: 87.5%
# Accuracy: 81.25%
# Accuracy: 85.9375%
# Accuracy: 93.75%
# Accuracy: 84.375%
# Accuracy: 79.6875%
# Accuracy: 90.625%
# Accuracy: 84.375%
# Accuracy: 79.6875%
# Accuracy: 73.4375%
# Accuracy: 89.0625%
# Accuracy: 92.1875%
# Accuracy: 84.375%
# Accuracy: 85.9375%
# Accuracy: 84.375%
# Accuracy: 82.8125%
# Accuracy: 84.375%
# Accuracy: 93.75%
# Accuracy: 85.9375%
# Accuracy: 68.75%
# Accuracy: 87.5%
# Accuracy: 93.75%
# Accuracy: 92.1875%
# Accuracy: 92.1875%
# Accuracy: 89.0625%
# Accuracy: 93.75%
# Accuracy: 85.9375%
# Accuracy: 89.0625%
# Accuracy: 95.3125%
# Accuracy: 84.375%
# Accuracy: 89.0625%
# Accuracy: 89.0625%
# Accuracy: 89.0625%
# Accuracy: 95.3125%
# Accuracy: 87.5%
# Accuracy: 87.5%
# Accuracy: 90.625%
# Accuracy: 87.5%
# Accuracy: 84.375%
# Accuracy: 90.625%
# Accuracy: 87.5%
# Accuracy: 96.875%
# Accuracy: 81.25%
# Accuracy: 85.9375%
# Accuracy: 92.1875%
# Accuracy: 79.6875%
# Accuracy: 87.5%
# Accuracy: 89.0625%
# Accuracy: 90.625%
# Accuracy: 87.5%
# Accuracy: 84.375%
# Accuracy: 87.5%
# Accuracy: 87.5%
# Accuracy: 90.625%
# Accuracy: 90.625%
# Accuracy: 90.625%
# Accuracy: 89.0625%
# Accuracy: 85.9375%
# Accuracy: 84.375%
# Accuracy: 85.9375%
# Accuracy: 92.1875%
# Accuracy: 84.375%
# Accuracy: 92.1875%
# Accuracy: 93.75%
# Accuracy: 85.9375%
# Accuracy: 90.625%
# Accuracy: 87.5%
# Accuracy: 93.75%
# Accuracy: 89.0625%
# Accuracy: 84.375%
# Accuracy: 92.1875%
# Accuracy: 87.5%
# Accuracy: 85.9375%
# Accuracy: 89.0625%
# Accuracy: 89.0625%
# Accuracy: 82.8125%
# Accuracy: 82.8125%
# Accuracy: 78.125%
# Accuracy: 90.625%
# Accuracy: 90.625%
# Accuracy: 87.5%
# Accuracy: 89.0625%
# Accuracy: 82.8125%
# Accuracy: 89.0625%
# Accuracy: 89.0625%
# Accuracy: 89.0625%
# Accuracy: 87.5%
# Accuracy: 90.625%
# Accuracy: 84.375%
# Accuracy: 81.25%
# Accuracy: 89.0625%
# Accuracy: 95.3125%
# Accuracy: 84.375%
# Accuracy: 89.0625%
# Accuracy: 87.5%
# Accuracy: 87.5%
# Accuracy: 89.0625%
# Accuracy: 84.375%
# Accuracy: 78.125%
# Accuracy: 85.9375%
# Accuracy: 90.625%
# Accuracy: 84.375%
# Accuracy: 85.9375%
# Accuracy: 90.625%
# Accuracy: 89.0625%
# Accuracy: 92.1875%
# Accuracy: 85.9375%
# Accuracy: 89.0625%
# Accuracy: 92.1875%
# Accuracy: 85.9375%
# Accuracy: 82.8125%
# Accuracy: 87.5%
# Accuracy: 87.5%
# Accuracy: 85.9375%
# Accuracy: 84.375%
# Accuracy: 81.25%
# Accuracy: 89.0625%
# Accuracy: 85.9375%
# Accuracy: 87.5%
# Accuracy: 73.4375%
# Accuracy: 89.0625%
# Accuracy: 93.75%
# Accuracy: 84.375%
# Accuracy: 90.625%
# Accuracy: 85.9375%
# Accuracy: 93.75%
# Accuracy: 90.625%
# Accuracy: 89.0625%
# Accuracy: 89.0625%
# Accuracy: 90.625%
# Accuracy: 81.25%
# Accuracy: 90.625%
# Accuracy: 89.0625%
# Accuracy: 81.25%
# Accuracy: 87.5%
# Accuracy: 90.625%
# Accuracy: 87.5%
# Accuracy: 89.0625%
# Accuracy: 93.75%
# Accuracy: 87.5%
# Accuracy: 79.6875%
# Accuracy: 89.0625%
# Accuracy: 89.0625%
# Accuracy: 84.375%
# Accuracy: 85.9375%
# Accuracy: 93.75%
# Accuracy: 85.9375%
# Accuracy: 81.25%
# Accuracy: 81.25%
# Accuracy: 85.9375%
# Accuracy: 87.5%
# Accuracy: 90.625%
# Accuracy: 90.625%
# Accuracy: 90.625%
# Accuracy: 89.0625%
# Accuracy: 85.9375%
# Accuracy: 82.8125%
# Accuracy: 87.5%
# Accuracy: 89.0625%
# Accuracy: 87.5%
# Accuracy: 89.0625%
# Accuracy: 82.8125%
# Accuracy: 85.9375%
# Accuracy: 92.1875%
# Accuracy: 87.5%
# Accuracy: 87.5%
# Accuracy: 87.5%
# Accuracy: 84.375%
# Accuracy: 79.6875%
# Accuracy: 93.75%
# Accuracy: 89.0625%
# Accuracy: 93.75%
# Accuracy: 78.125%
# Accuracy: 89.0625%
# Accuracy: 95.3125%
# Accuracy: 87.5%
# Accuracy: 93.75%
# Accuracy: 90.625%
# Accuracy: 89.0625%
# Accuracy: 87.5%
# Accuracy: 90.625%
# Accuracy: 87.5%
# Accuracy: 81.25%
# Accuracy: 82.8125%
# Accuracy: 79.6875%
# Accuracy: 89.0625%
# Accuracy: 92.1875%
# Accuracy: 92.1875%
# Accuracy: 89.0625%
# Accuracy: 76.5625%
# Accuracy: 90.625%
# Accuracy: 84.375%
# Accuracy: 81.25%
# Accuracy: 87.5%
# Accuracy: 81.25%
# Accuracy: 92.1875%
# Accuracy: 93.75%
# Accuracy: 84.375%
# Accuracy: 89.0625%
# Accuracy: 89.0625%
# Accuracy: 90.625%
# Accuracy: 87.5%
# Accuracy: 89.0625%
# Accuracy: 79.6875%
# Accuracy: 90.625%
# Accuracy: 85.9375%
# Accuracy: 96.875%
# Accuracy: 96.875%
# Accuracy: 84.375%
# Accuracy: 93.75%
# Accuracy: 93.75%
# Accuracy: 87.5%
# Accuracy: 85.9375%
# Accuracy: 90.625%
# Accuracy: 89.0625%
# Accuracy: 89.0625%
# Accuracy: 87.5%
# Accuracy: 84.375%
# Accuracy: 84.375%
# Accuracy: 81.25%
# Accuracy: 84.375%
# Accuracy: 93.75%
# Accuracy: 92.1875%
# Accuracy: 90.625%
# Accuracy: 90.625%
# Accuracy: 95.3125%
# Accuracy: 95.3125%
# Accuracy: 82.8125%
# Accuracy: 85.9375%
# Accuracy: 93.75%
# Accuracy: 90.625%
# Accuracy: 84.375%
# Accuracy: 89.0625%
# Accuracy: 90.625%
# Accuracy: 93.75%
# Accuracy: 85.9375%
# Accuracy: 89.0625%
# Accuracy: 79.6875%
# Accuracy: 85.9375%
# Accuracy: 89.0625%
# Accuracy: 73.4375%
# Accuracy: 84.375%
# Accuracy: 92.1875%
# Accuracy: 82.8125%
# Accuracy: 82.8125%
# Accuracy: 82.8125%
# Accuracy: 89.0625%
# Accuracy: 87.5%
# Accuracy: 89.0625%
# Accuracy: 85.9375%
# Accuracy: 90.625%
# Accuracy: 89.0625%
# Accuracy: 82.8125%
# Accuracy: 89.0625%
# Accuracy: 87.5%
# Accuracy: 89.0625%
# Accuracy: 90.625%
# Accuracy: 87.5%
# Accuracy: 92.1875%
# Accuracy: 84.375%
# Accuracy: 82.8125%
# Accuracy: 89.0625%
# Accuracy: 84.375%
# Accuracy: 81.25%
# Accuracy: 92.1875%
# Accuracy: 90.625%
# Accuracy: 92.1875%
# Accuracy: 85.9375%
# Accuracy: 89.0625%
# Accuracy: 84.375%
# Accuracy: 90.625%
# Accuracy: 85.9375%
# Accuracy: 82.8125%
# Accuracy: 84.375%
# Accuracy: 87.5%
# Accuracy: 82.8125%
# Accuracy: 89.0625%
# Accuracy: 90.625%
# Accuracy: 87.5%
# Accuracy: 84.375%
# Accuracy: 84.375%
# Accuracy: 85.9375%
# Accuracy: 82.8125%
# Accuracy: 90.625%
# Accuracy: 85.9375%
# Accuracy: 92.1875%
# Accuracy: 78.125%
# Accuracy: 85.9375%
# Accuracy: 82.8125%
# Accuracy: 76.5625%
# Accuracy: 89.0625%
# Accuracy: 84.375%
# Accuracy: 85.9375%
# Accuracy: 85.9375%
# Accuracy: 92.1875%
# Accuracy: 84.375%
# Accuracy: 87.5%
# Accuracy: 84.375%
# Accuracy: 90.625%
# Accuracy: 85.9375%
# Accuracy: 89.0625%
# Accuracy: 87.5%
# Accuracy: 87.5%
# Accuracy: 87.5%
# Accuracy: 89.0625%
# Accuracy: 87.5%
# Accuracy: 87.5%
# Accuracy: 85.9375%
# Accuracy: 87.5%
# Accuracy: 92.1875%
# Accuracy: 87.5%
# Accuracy: 85.9375%
# Accuracy: 82.8125%
# Accuracy: 87.5%
# Accuracy: 82.8125%
# Accuracy: 87.5%
# Accuracy: 93.75%
# Accuracy: 82.8125%
# Accuracy: 93.75%
# Accuracy: 84.375%
# Accuracy: 92.1875%
# Accuracy: 85.9375%
# Accuracy: 84.375%
# Accuracy: 89.0625%
# Accuracy: 87.5%
# Accuracy: 87.5%
# Accuracy: 85.9375%
# Accuracy: 85.9375%
# Accuracy: 84.375%
# Accuracy: 93.75%
# Accuracy: 79.6875%
# Accuracy: 89.0625%
# Accuracy: 85.9375%
# Accuracy: 87.5%
# Accuracy: 89.0625%
# Accuracy: 89.0625%
# Accuracy: 85.9375%
# Accuracy: 90.625%
# Accuracy: 90.625%
# Accuracy: 85.9375%
# Accuracy: 78.125%
# Accuracy: 89.0625%
# Accuracy: 85.9375%
# Accuracy: 82.8125%
# Accuracy: 87.5%
# Accuracy: 81.25%
# Accuracy: 93.75%
# Accuracy: 89.0625%
# Accuracy: 90.625%
# Accuracy: 84.375%
# Accuracy: 85.9375%
# Accuracy: 87.5%
# Accuracy: 96.875%
# Accuracy: 84.375%
# Accuracy: 93.75%
# Accuracy: 90.625%
# Accuracy: 84.375%
# Accuracy: 79.6875%
# Accuracy: 84.375%
# Accuracy: 89.0625%
# Accuracy: 89.0625%
# Accuracy: 87.5%
# Accuracy: 84.375%
# Accuracy: 85.9375%
# Accuracy: 85.9375%
# Accuracy: 90.625%
# Accuracy: 85.9375%
# Accuracy: 84.375%
# Accuracy: 87.5%
# Accuracy: 95.3125%
# Accuracy: 76.5625%
# Accuracy: 87.5%
# Accuracy: 85.9375%
# Accuracy: 87.5%
# Accuracy: 90.625%
# Accuracy: 82.8125%
# Accuracy: 90.625%
# Accuracy: 89.0625%
# Accuracy: 82.8125%
# Accuracy: 82.8125%
# Accuracy: 82.8125%
# Accuracy: 90.625%
# Accuracy: 95.3125%
# Accuracy: 84.375%
# Accuracy: 87.5%
# Accuracy: 87.5%
# Accuracy: 89.0625%
# Accuracy: 84.375%
# Accuracy: 93.75%
# Accuracy: 87.5%
# Accuracy: 89.0625%
# Accuracy: 90.625%
# Accuracy: 89.0625%
# Accuracy: 93.75%
# Accuracy: 93.75%
# Accuracy: 90.625%
# Accuracy: 87.5%
# Accuracy: 85.9375%
# Accuracy: 89.0625%
# Accuracy: 90.625%
# Accuracy: 95.3125%
# Accuracy: 90.625%
# Accuracy: 89.0625%
# Accuracy: 81.25%
# Accuracy: 93.75%
# Accuracy: 92.1875%
# Accuracy: 89.0625%
# Accuracy: 82.8125%
# Accuracy: 89.0625%
# Accuracy: 95.3125%
# Accuracy: 84.375%
# Accuracy: 84.375%
# Accuracy: 90.625%
# Accuracy: 89.0625%
# Accuracy: 84.375%
# Accuracy: 92.1875%
# Accuracy: 84.375%
# Accuracy: 84.375%
# Accuracy: 90.625%
# Accuracy: 89.0625%
# Accuracy: 89.0625%
# Accuracy: 95.3125%
# Accuracy: 82.8125%
# Accuracy: 89.0625%
# Accuracy: 90.625%
# Accuracy: 95.3125%
# Accuracy: 78.125%
# Accuracy: 92.1875%
# Accuracy: 90.625%
# Accuracy: 87.5%
# Accuracy: 89.0625%
# Accuracy: 82.8125%
# Accuracy: 95.3125%
# Accuracy: 89.0625%
# Accuracy: 90.625%
# Accuracy: 87.5%
# Accuracy: 85.9375%
# Accuracy: 90.625%
# Accuracy: 89.0625%
# Accuracy: 84.375%
# Accuracy: 87.5%
# Accuracy: 85.9375%
# Accuracy: 90.625%
# Accuracy: 90.625%
# Accuracy: 85.9375%
# Accuracy: 84.375%
# Accuracy: 85.9375%
# Accuracy: 84.375%
# Accuracy: 90.625%
# Accuracy: 84.375%
# Accuracy: 82.8125%
# Accuracy: 85.9375%
# Accuracy: 89.0625%
# Accuracy: 85.9375%
# Accuracy: 87.5%
# Accuracy: 85.9375%
# Accuracy: 90.625%
# Accuracy: 84.375%
# Accuracy: 85.9375%
# Accuracy: 87.5%
# Accuracy: 89.0625%
# Accuracy: 92.1875%
# Accuracy: 89.0625%
# Accuracy: 85.9375%
# Accuracy: 81.25%
# Accuracy: 85.9375%
# Accuracy: 90.625%
# Accuracy: 85.9375%
# Accuracy: 93.75%
# Accuracy: 84.375%
# Accuracy: 89.0625%
# Accuracy: 89.0625%
# Accuracy: 84.375%
# Accuracy: 79.6875%
# Accuracy: 89.0625%
# Accuracy: 84.375%
# Accuracy: 82.8125%
# Accuracy: 81.25%
# Accuracy: 89.0625%
# Accuracy: 90.625%
# Accuracy: 90.625%
# Accuracy: 93.75%
# Accuracy: 84.375%
# Accuracy: 95.3125%
# Accuracy: 89.0625%
# Accuracy: 95.3125%
# Accuracy: 82.8125%
# Accuracy: 92.1875%
# Accuracy: 82.8125%
# Accuracy: 87.5%
# Accuracy: 75.0%
# Accuracy: 84.375%
# Accuracy: 89.0625%
# Accuracy: 84.375%
# Accuracy: 92.1875%
# Accuracy: 89.0625%
# Accuracy: 90.625%
# Accuracy: 84.375%
# Accuracy: 92.1875%
# Accuracy: 89.0625%
# Accuracy: 87.5%
# Accuracy: 90.625%
# Accuracy: 79.6875%
# Accuracy: 89.0625%
# Accuracy: 81.25%
# Accuracy: 84.375%
# Accuracy: 89.0625%
# Accuracy: 89.0625%
# Accuracy: 93.75%
# Accuracy: 82.8125%
# Accuracy: 82.8125%
# Accuracy: 89.0625%
# Accuracy: 85.9375%
# Accuracy: 87.5%
# Accuracy: 90.625%
# Accuracy: 81.25%
# Accuracy: 89.0625%
# Accuracy: 79.6875%
# Accuracy: 85.9375%
# Accuracy: 85.9375%
# Accuracy: 82.8125%
# Accuracy: 93.75%
# Accuracy: 85.9375%
# Accuracy: 93.75%
# Accuracy: 82.8125%
# Accuracy: 85.9375%
# Accuracy: 85.9375%
# Accuracy: 81.25%
# Accuracy: 76.5625%
# Accuracy: 85.9375%
# Accuracy: 92.1875%
# Accuracy: 84.375%
# Accuracy: 82.8125%
# Accuracy: 85.9375%
# Accuracy: 85.9375%
# Accuracy: 90.625%
# Accuracy: 87.5%
# Accuracy: 92.1875%
# Accuracy: 79.6875%
# Accuracy: 85.9375%
# Accuracy: 90.625%
# Accuracy: 87.5%
# Accuracy: 95.3125%
# Accuracy: 81.25%
# Accuracy: 93.75%
# Accuracy: 87.5%
# Accuracy: 76.5625%
# Accuracy: 89.0625%
# Accuracy: 82.8125%
# Accuracy: 90.625%
# Accuracy: 81.25%
# Accuracy: 92.1875%
# Accuracy: 87.5%
# Accuracy: 79.6875%
# Accuracy: 93.75%
# Accuracy: 85.9375%
# Accuracy: 85.9375%
# Accuracy: 82.8125%
# Accuracy: 93.75%
# Accuracy: 79.6875%
# Accuracy: 89.0625%
# Accuracy: 90.625%
# Accuracy: 84.375%
# Accuracy: 90.625%
# Accuracy: 87.5%
# Accuracy: 79.6875%
# Accuracy: 84.375%
# Accuracy: 90.625%
# Accuracy: 92.1875%
# Accuracy: 89.0625%
# Accuracy: 87.5%
# Accuracy: 85.9375%
# Accuracy: 90.625%
# Accuracy: 89.0625%
# Accuracy: 87.5%
# Accuracy: 84.375%
# Accuracy: 90.625%
# Accuracy: 92.1875%
# Accuracy: 90.625%
# Accuracy: 85.9375%
# Accuracy: 92.1875%
# Accuracy: 85.9375%
# Accuracy: 89.0625%
# Accuracy: 87.5%
# Accuracy: 89.0625%
# Accuracy: 89.0625%
# Accuracy: 84.375%
# Accuracy: 93.75%
# Accuracy: 84.375%
# Accuracy: 90.625%
# Accuracy: 87.5%
# Accuracy: 90.625%
# Accuracy: 82.8125%
# Accuracy: 93.75%
# Accuracy: 93.75%
# Accuracy: 79.6875%
# Accuracy: 92.1875%
# Accuracy: 92.1875%
# Accuracy: 84.375%
# Accuracy: 89.0625%
# Accuracy: 84.375%
# Accuracy: 84.375%
# Accuracy: 90.625%
# Accuracy: 82.8125%
# Accuracy: 79.6875%
# Accuracy: 79.6875%
# Accuracy: 81.25%
# Accuracy: 84.375%
# Accuracy: 82.8125%
# Accuracy: 90.625%
# Accuracy: 84.375%
# Accuracy: 93.75%
# Accuracy: 92.1875%
# Accuracy: 92.1875%
# Accuracy: 92.1875%
# Accuracy: 87.5%
# Accuracy: 92.1875%
# Accuracy: 92.1875%
# Accuracy: 85.9375%
# Accuracy: 85.9375%
# Accuracy: 84.375%
# Accuracy: 90.625%
# Accuracy: 85.9375%
# Accuracy: 84.375%
# Accuracy: 85.9375%
# Accuracy: 82.8125%
# Accuracy: 90.625%
# Accuracy: 89.0625%
# Accuracy: 84.375%
# Accuracy: 90.625%
# Accuracy: 90.625%
# Accuracy: 95.3125%
# Accuracy: 92.1875%
# Accuracy: 90.625%
# Accuracy: 90.625%
# Accuracy: 89.0625%
# Accuracy: 87.5%
# Accuracy: 78.125%
# Accuracy: 89.0625%
# Accuracy: 87.5%
# Accuracy: 89.0625%
# Accuracy: 81.25%
# Accuracy: 90.625%
# Accuracy: 87.5%
# Accuracy: 90.625%
# Accuracy: 89.0625%
# Accuracy: 87.5%
# Accuracy: 68.75%
# Accuracy: 78.125%
# Accuracy: 92.1875%
# Accuracy: 89.0625%
# Accuracy: 79.6875%
# Accuracy: 93.75%
# Accuracy: 89.0625%
# Accuracy: 87.5%
# Accuracy: 90.625%
# Accuracy: 85.9375%
# Accuracy: 81.25%
# Accuracy: 81.25%
# Accuracy: 90.625%
# Accuracy: 87.5%
# Accuracy: 89.0625%
# Accuracy: 90.625%
# Accuracy: 92.1875%
# Accuracy: 87.5%
# Accuracy: 90.625%
# Accuracy: 84.375%
# Accuracy: 89.0625%
# Accuracy: 85.9375%
# Accuracy: 92.1875%
# Accuracy: 89.0625%
# Accuracy: 84.375%
# Accuracy: 87.5%
# Accuracy: 95.3125%
# Accuracy: 87.5%
# Accuracy: 85.9375%
# Accuracy: 85.9375%
# Accuracy: 87.5%
# Accuracy: 82.8125%
# Accuracy: 85.9375%
# Accuracy: 85.9375%
# Accuracy: 95.3125%
# Accuracy: 95.3125%
# Accuracy: 85.9375%
# Accuracy: 89.0625%
# Accuracy: 89.0625%
# Accuracy: 90.625%
# Accuracy: 93.75%
# Accuracy: 85.9375%
# Accuracy: 90.625%
# Accuracy: 93.75%
# Accuracy: 92.1875%
# Accuracy: 85.9375%
# Accuracy: 85.9375%
# Accuracy: 89.0625%
# Accuracy: 81.25%
# Accuracy: 84.375%
# Accuracy: 89.0625%
# Accuracy: 90.625%
# Accuracy: 90.625%
# Accuracy: 81.25%
# Accuracy: 82.8125%
# Accuracy: 87.5%
# Accuracy: 90.625%
# Accuracy: 87.5%
# Accuracy: 82.8125%
# Accuracy: 82.8125%
# Accuracy: 92.1875%
# Accuracy: 85.9375%
# Accuracy: 76.5625%
# Accuracy: 81.25%
# Accuracy: 95.3125%
# Accuracy: 87.5%
# Accuracy: 92.1875%
# Accuracy: 87.5%
# Accuracy: 81.25%
# Accuracy: 85.9375%
# Accuracy: 92.1875%
# Accuracy: 87.5%
# Accuracy: 85.9375%
# Accuracy: 93.75%
# Accuracy: 93.75%
# Accuracy: 85.9375%
# Accuracy: 95.3125%
# Accuracy: 79.6875%
# Accuracy: 87.5%
# Accuracy: 82.8125%
# Accuracy: 93.75%
# Accuracy: 78.125%
# Accuracy: 90.625%
# Accuracy: 78.125%
# Accuracy: 85.9375%
# Accuracy: 87.5%
# Accuracy: 81.25%
# Accuracy: 90.625%
# Accuracy: 90.625%
# Accuracy: 92.1875%
# Accuracy: 85.9375%
# Accuracy: 89.0625%
# Accuracy: 89.0625%
# Accuracy: 89.0625%
# Accuracy: 90.625%
# Accuracy: 89.0625%
# Accuracy: 89.0625%
# Accuracy: 92.1875%
# Accuracy: 85.9375%
# Accuracy: 89.0625%
# Accuracy: 87.5%
# Accuracy: 85.9375%
# Accuracy: 85.9375%
# Accuracy: 81.25%
# Accuracy: 85.9375%
# Accuracy: 90.625%
# Accuracy: 90.625%
# Accuracy: 89.0625%
# Accuracy: 85.9375%
# Accuracy: 87.5%
# Accuracy: 89.0625%
# Accuracy: 90.625%
# Accuracy: 87.5%
# Accuracy: 93.75%
# Accuracy: 82.8125%
# Accuracy: 89.0625%
# Accuracy: 93.75%
# Accuracy: 89.0625%
# Accuracy: 90.625%
# Accuracy: 90.625%
# Accuracy: 87.5%
# Accuracy: 85.9375%
# Accuracy: 90.625%
# Accuracy: 95.3125%
# Accuracy: 84.375%
# Accuracy: 89.0625%
# Accuracy: 89.0625%
# Accuracy: 84.375%
# Accuracy: 89.0625%
# Accuracy: 89.0625%
# Accuracy: 90.625%
# Accuracy: 92.1875%
# Accuracy: 85.9375%
# Accuracy: 84.375%
# Accuracy: 92.1875%
# Accuracy: 82.8125%
# Accuracy: 90.625%
# Accuracy: 85.9375%
# Accuracy: 90.625%
# Accuracy: 87.5%
# Accuracy: 87.5%
# Accuracy: 81.25%
# Accuracy: 85.9375%
# ...
# Accuracy: 89.0625%
# Accuracy: 95.3125%
# Accuracy: 89.0625%
# Accuracy: 95.3125%
# Accuracy: 90.625%
# Accuracy: 81.25%
# Accuracy: 92.1875%
# Accuracy: 87.5%
# Accuracy: 93.75%
# Accuracy: 93.75%
# Accuracy: 84.375%
# Accuracy: 95.3125%
# Accuracy: 93.75%
# Accuracy: 85.9375%
# Accuracy: 87.5%
# Accuracy: 84.375%
# Accuracy: 89.0625%
# Accuracy: 89.0625%
# Accuracy: 90.625%
# Accuracy: 90.625%
# Accuracy: 93.75%
# Accuracy: 87.5%
# Accuracy: 90.625%
# Accuracy: 87.5%
# Accuracy: 87.5%
# Accuracy: 90.625%
# Accuracy: 84.375%
# Accuracy: 92.1875%
# Accuracy: 85.9375%
# Accuracy: 82.8125%
# Accuracy: 85.9375%
# Accuracy: 87.5%
# Accuracy: 85.9375%
# Accuracy: 87.5%
# Accuracy: 92.1875%
# Accuracy: 90.625%
# Accuracy: 87.5%
# Accuracy: 93.75%
# Accuracy: 90.625%
# Accuracy: 90.625%
# Accuracy: 78.125%
# Accuracy: 87.5%
# Accuracy: 90.625%
# Accuracy: 93.75%
# Accuracy: 89.0625%
# Accuracy: 90.625%
# Accuracy: 89.0625%
# Accuracy: 92.1875%
# Accuracy: 89.0625%
# Accuracy: 89.0625%
# Accuracy: 85.9375%
# Accuracy: 79.6875%
# Accuracy: 92.1875%
# Accuracy: 90.625%
# Accuracy: 85.9375%
# Accuracy: 96.875%
# Accuracy: 93.75%
# Accuracy: 90.625%
# Accuracy: 82.8125%
# Accuracy: 82.8125%
# Accuracy: 90.625%
# Accuracy: 84.375%
# Accuracy: 85.9375%
# Accuracy: 90.625%
# Accuracy: 93.75%
# Accuracy: 78.125%
# Accuracy: 89.0625%
# Accuracy: 92.1875%
# Accuracy: 84.375%
# Accuracy: 79.6875%
# Accuracy: 89.0625%
# Accuracy: 93.75%
# Accuracy: 85.9375%
# Accuracy: 84.375%
# Accuracy: 89.0625%
# Accuracy: 84.375%
# Accuracy: 92.1875%
# Accuracy: 82.8125%
# Accuracy: 79.6875%
# Accuracy: 89.0625%
# Accuracy: 90.625%
# Accuracy: 87.5%
# Accuracy: 90.625%
# Accuracy: 85.9375%
# Accuracy: 84.375%
# Accuracy: 90.625%
# Accuracy: 89.0625%
# Accuracy: 90.625%
# Accuracy: 89.0625%
# Accuracy: 90.625%
# Accuracy: 85.9375%
# Accuracy: 89.0625%
# Accuracy: 96.875%
# Accuracy: 79.6875%
# Accuracy: 89.0625%
# Accuracy: 90.625%
# Accuracy: 84.375%
# Accuracy: 81.25%
# Accuracy: 89.0625%
# Accuracy: 89.0625%
# Accuracy: 85.9375%
# Accuracy: 87.5%
# Accuracy: 87.5%
# Accuracy: 93.75%
# Accuracy: 96.875%
# Accuracy: 85.9375%
# Accuracy: 93.75%
# Accuracy: 90.625%
# Accuracy: 85.9375%
# Accuracy: 87.5%
# Accuracy: 93.75%
# Accuracy: 87.5%
# Accuracy: 89.0625%
# Accuracy: 89.0625%
# Accuracy: 93.75%
# Accuracy: 90.625%
# Accuracy: 90.625%
# Accuracy: 85.9375%
# Accuracy: 90.625%
# Accuracy: 82.8125%
# Accuracy: 84.375%
# Accuracy: 92.1875%
# Accuracy: 89.0625%
# Accuracy: 96.875%
# Accuracy: 84.375%
# Accuracy: 89.0625%
# Accuracy: 85.9375%
# Accuracy: 85.9375%
# Accuracy: 92.1875%
# Accuracy: 85.9375%
# Accuracy: 85.9375%
# Accuracy: 96.875%
# Accuracy: 82.8125%
# Accuracy: 89.0625%
# Accuracy: 82.8125%
# Accuracy: 95.3125%
# Accuracy: 92.1875%
# Accuracy: 92.1875%
# Accuracy: 87.5%
# Accuracy: 90.625%
# Accuracy: 89.0625%
# Accuracy: 87.5%
# Accuracy: 95.3125%
# Accuracy: 89.0625%
# Accuracy: 87.5%
# Accuracy: 87.5%
# Accuracy: 85.9375%
# Accuracy: 85.9375%
# Accuracy: 85.9375%
# Accuracy: 82.8125%
# Accuracy: 90.625%
# Accuracy: 90.625%
# Accuracy: 87.5%
# Accuracy: 82.8125%
# Accuracy: 87.5%
# Accuracy: 93.75%
# Accuracy: 89.0625%
# Accuracy: 90.625%
# Accuracy: 89.0625%
# Accuracy: 85.9375%
# Accuracy: 81.25%
# Accuracy: 87.5%
# Accuracy: 87.5%
# Accuracy: 89.0625%
# Accuracy: 84.375%
# Accuracy: 87.5%
# Accuracy: 85.9375%
# Accuracy: 96.875%
# Accuracy: 85.9375%
# Accuracy: 79.6875%
# Accuracy: 87.5%
# Accuracy: 85.9375%
# Accuracy: 90.625%
# Accuracy: 89.0625%
# Accuracy: 87.5%
# Accuracy: 89.0625%
# Accuracy: 92.1875%
# Accuracy: 85.9375%
# Accuracy: 85.9375%
# Accuracy: 84.375%
# Accuracy: 85.9375%
# Accuracy: 85.9375%
# Accuracy: 84.375%
# Accuracy: 89.0625%
# Accuracy: 81.25%
# Accuracy: 90.625%
# Accuracy: 89.0625%
# Accuracy: 84.375%
# Accuracy: 89.0625%
# Accuracy: 85.9375%
# Accuracy: 95.3125%
# Accuracy: 82.8125%
# Accuracy: 90.625%
# Accuracy: 85.9375%
# Accuracy: 92.1875%
# Accuracy: 85.9375%
# Accuracy: 90.625%
# Accuracy: 90.625%
# Accuracy: 85.9375%
# Accuracy: 87.5%
# Accuracy: 90.625%
# Accuracy: 89.0625%
# Accuracy: 90.625%
# Accuracy: 87.5%
# Accuracy: 89.0625%
# Accuracy: 89.0625%
# Accuracy: 84.375%
# Accuracy: 89.0625%
# Accuracy: 95.3125%
# Accuracy: 78.125%
# Accuracy: 81.25%
# Accuracy: 89.0625%
# Accuracy: 93.75%
# Accuracy: 81.25%
# Accuracy: 87.5%
# Accuracy: 84.375%
# Accuracy: 87.5%
# Accuracy: 85.9375%
# Accuracy: 82.8125%
# Accuracy: 95.3125%
# Accuracy: 87.5%
# Accuracy: 93.75%
# Accuracy: 87.5%
# Accuracy: 85.9375%
# Accuracy: 92.1875%
# Accuracy: 85.9375%
# Accuracy: 89.0625%
# Accuracy: 92.1875%
# Accuracy: 90.625%
# Accuracy: 90.625%
# Accuracy: 79.6875%
# Accuracy: 85.9375%
# Accuracy: 82.8125%
# Accuracy: 84.375%
# Accuracy: 79.6875%
# Accuracy: 85.9375%
# Accuracy: 81.25%
# Accuracy: 95.3125%
# Accuracy: 87.5%
# Accuracy: 87.5%
# Accuracy: 90.625%
# Accuracy: 85.9375%
# Accuracy: 84.375%
# Accuracy: 93.75%
# Accuracy: 87.5%
# Accuracy: 89.0625%
# Accuracy: 85.9375%
# Accuracy: 85.9375%
# Accuracy: 87.5%
# Accuracy: 85.9375%
# Accuracy: 84.375%
# Accuracy: 90.625%
# Accuracy: 84.375%
# Accuracy: 89.0625%
# Accuracy: 81.25%
# Accuracy: 87.5%
# Accuracy: 90.625%
# Accuracy: 90.625%
# Accuracy: 85.9375%
# Accuracy: 89.0625%
# Accuracy: 85.9375%
# Accuracy: 92.1875%
# Accuracy: 89.0625%
# Accuracy: 92.1875%
# Accuracy: 81.25%
# Accuracy: 90.625%
# Accuracy: 93.75%
# Accuracy: 92.1875%
# Accuracy: 92.1875%
# Accuracy: 93.75%
# Accuracy: 90.625%
# Accuracy: 79.6875%
# Accuracy: 85.9375%
# Accuracy: 81.25%
# Accuracy: 84.375%
# Accuracy: 92.1875%
# Accuracy: 95.3125%
# Accuracy: 92.1875%
# Accuracy: 85.9375%
# Accuracy: 90.625%
# Accuracy: 84.375%
# Accuracy: 90.625%
# Accuracy: 84.375%
# Accuracy: 87.5%
# Accuracy: 90.625%
# Accuracy: 76.5625%
# Accuracy: 84.375%
# Accuracy: 89.0625%
# Accuracy: 85.9375%
# Accuracy: 84.375%
# Accuracy: 95.3125%
# Accuracy: 95.3125%
# Accuracy: 89.0625%
# Accuracy: 89.0625%
# Accuracy: 92.1875%
# Accuracy: 93.75%
# Accuracy: 85.9375%
# Accuracy: 90.625%
# Accuracy: 84.375%
# Accuracy: 90.625%
# Accuracy: 84.375%
# Accuracy: 87.5%
# Accuracy: 95.3125%
# Accuracy: 84.375%
# Accuracy: 93.75%
# Accuracy: 89.0625%
# Accuracy: 87.5%
# Accuracy: 93.75%
# Accuracy: 87.5%
# Accuracy: 85.9375%
# Accuracy: 87.5%
# Accuracy: 90.625%
# Accuracy: 85.9375%
# Accuracy: 85.9375%
# Accuracy: 85.9375%
# Accuracy: 87.5%
# Accuracy: 90.625%
# Accuracy: 92.1875%
# Accuracy: 81.25%
# Accuracy: 82.8125%
# Accuracy: 90.625%
# Accuracy: 90.625%
# Accuracy: 87.5%
# Accuracy: 85.9375%
# Accuracy: 84.375%
# Accuracy: 93.75%
# Accuracy: 90.625%
# Accuracy: 87.5%
# Accuracy: 92.1875%
# Accuracy: 82.8125%
# Accuracy: 90.625%
# Accuracy: 90.625%
# Accuracy: 85.9375%
# Accuracy: 79.6875%
# Accuracy: 90.625%
# Accuracy: 90.625%
# Accuracy: 89.0625%
# Accuracy: 85.9375%
# Accuracy: 89.0625%
# Accuracy: 95.3125%
# Accuracy: 92.1875%
# Accuracy: 87.5%
# Accuracy: 92.1875%
# Accuracy: 85.9375%
# Accuracy: 90.625%
# Accuracy: 87.5%
# Accuracy: 87.5%
# Accuracy: 92.1875%
# Accuracy: 87.5%
# Accuracy: 87.5%
# Accuracy: 90.625%
# Accuracy: 85.9375%
# Accuracy: 87.5%
# Accuracy: 87.5%
# Accuracy: 89.0625%
# Accuracy: 89.0625%
# Accuracy: 90.625%
# Accuracy: 92.1875%
# Accuracy: 87.5%
# Accuracy: 93.75%
# Accuracy: 89.0625%
# Accuracy: 82.8125%
# Accuracy: 87.5%
# Accuracy: 92.1875%
# Accuracy: 84.375%
# Accuracy: 95.3125%
# Accuracy: 85.9375%
# Accuracy: 87.5%
# Accuracy: 87.5%
# Accuracy: 76.5625%
# Accuracy: 93.75%
# Accuracy: 93.75%
# Accuracy: 92.1875%
# Accuracy: 87.5%
# Accuracy: 87.5%
# Accuracy: 87.5%
# Accuracy: 93.75%
# Accuracy: 95.3125%
# Accuracy: 76.5625%
# Accuracy: 87.5%
# Accuracy: 87.5%
# Accuracy: 82.8125%
# Accuracy: 87.5%
# Accuracy: 85.9375%
# Accuracy: 84.375%
# Accuracy: 82.8125%
# Accuracy: 84.375%
# Accuracy: 87.5%
# Accuracy: 87.5%
# Accuracy: 85.9375%
# Accuracy: 90.625%
# Accuracy: 87.5%
# Accuracy: 90.625%
# Accuracy: 100.0%
# Accuracy: 90.625%
# Accuracy: 87.5%
# Accuracy: 85.9375%
# Accuracy: 89.0625%
# Accuracy: 87.5%
# Accuracy: 92.1875%
# Accuracy: 85.9375%
# Accuracy: 85.9375%
# Accuracy: 87.5%
# Accuracy: 85.9375%
# Accuracy: 90.625%
# Accuracy: 85.9375%
# Accuracy: 92.1875%
# Accuracy: 79.6875%
# Accuracy: 89.0625%
# Accuracy: 81.25%
# Accuracy: 84.375%
# Accuracy: 93.75%
# Accuracy: 89.0625%
# Accuracy: 95.3125%
# Accuracy: 84.375%
# Accuracy: 95.3125%
# Accuracy: 92.1875%
# Accuracy: 89.0625%
# Accuracy: 93.75%
# Accuracy: 93.75%
# Accuracy: 87.5%
# Accuracy: 87.5%
# Accuracy: 84.375%
# Accuracy: 96.875%
# Accuracy: 92.1875%
# Accuracy: 82.8125%
# Accuracy: 87.5%
# Accuracy: 87.5%
# Accuracy: 84.375%
# Accuracy: 87.5%
# Accuracy: 84.375%
# Accuracy: 89.0625%
# Accuracy: 89.0625%
# Accuracy: 90.625%
# Accuracy: 93.75%
# Accuracy: 81.25%
# Accuracy: 87.5%
# Accuracy: 78.125%
# Accuracy: 89.0625%
# Accuracy: 92.1875%
# Accuracy: 85.9375%
# Accuracy: 84.375%
# Accuracy: 82.8125%
# Accuracy: 84.375%
# Accuracy: 84.375%
# Accuracy: 90.625%
# Accuracy: 82.8125%
# Accuracy: 89.0625%
# Accuracy: 78.125%
# Accuracy: 84.375%
# Accuracy: 90.625%
# Accuracy: 89.0625%
# Accuracy: 85.9375%
# Accuracy: 90.625%
# Accuracy: 96.875%
# Accuracy: 82.8125%
# Accuracy: 85.9375%
# Accuracy: 84.375%
# Accuracy: 89.0625%
# Accuracy: 92.1875%
# Accuracy: 84.375%
# Accuracy: 96.875%
# Accuracy: 90.625%
# Accuracy: 90.625%
# Accuracy: 85.9375%
# Accuracy: 90.625%
# Accuracy: 89.0625%
# Accuracy: 85.9375%
# Accuracy: 93.75%
# Accuracy: 89.0625%
# Accuracy: 84.375%
# Accuracy: 82.8125%
# Accuracy: 89.0625%
# Accuracy: 87.5%
# Accuracy: 85.9375%
# Accuracy: 84.375%
# Accuracy: 89.0625%
# Accuracy: 95.3125%
# Accuracy: 78.125%
# Accuracy: 85.9375%
# Accuracy: 92.1875%
# Accuracy: 90.625%
# Accuracy: 95.3125%
# Accuracy: 92.1875%
# Accuracy: 90.625%
# Accuracy: 87.5%
# Accuracy: 89.0625%
# Accuracy: 89.0625%
# Accuracy: 89.0625%
# Accuracy: 93.75%
# Accuracy: 92.1875%
# Accuracy: 92.1875%
# Accuracy: 79.6875%
# Accuracy: 89.0625%
# Accuracy: 84.375%
# Accuracy: 82.8125%
# Accuracy: 90.625%
# Accuracy: 82.8125%
# Accuracy: 87.5%
# Accuracy: 81.25%
# Accuracy: 85.9375%
# Accuracy: 93.75%
# Accuracy: 93.75%
# Accuracy: 89.0625%
# Accuracy: 85.9375%
# Accuracy: 90.625%
# Accuracy: 89.0625%
# Accuracy: 85.9375%
# Accuracy: 89.0625%
# Accuracy: 89.0625%
# Accuracy: 92.1875%
# Accuracy: 90.625%
# Accuracy: 92.1875%
# Accuracy: 89.0625%
# Accuracy: 82.8125%
# Accuracy: 92.1875%
# Accuracy: 89.0625%
# Accuracy: 87.5%
# Accuracy: 95.3125%
# Accuracy: 89.0625%
# Accuracy: 84.375%
# Accuracy: 90.625%
# Accuracy: 92.1875%
# Accuracy: 85.9375%
# Accuracy: 93.75%
# Accuracy: 84.375%
# Accuracy: 89.0625%
# Accuracy: 85.9375%
# Accuracy: 89.0625%
# Accuracy: 81.25%
# Accuracy: 92.1875%
# Accuracy: 85.9375%
# Accuracy: 90.625%
# Accuracy: 89.0625%
# Accuracy: 87.5%
# Accuracy: 87.5%
# Accuracy: 93.75%
# Accuracy: 90.625%
# Accuracy: 85.9375%
# Accuracy: 87.5%
# Accuracy: 90.625%
# Accuracy: 89.0625%
# Accuracy: 89.0625%
# Accuracy: 81.25%
# Accuracy: 92.1875%
# Accuracy: 85.9375%
# Accuracy: 82.8125%
# Accuracy: 89.0625%
# Accuracy: 85.9375%
# Accuracy: 87.5%
# Accuracy: 82.8125%
# Accuracy: 89.0625%
# Accuracy: 92.1875%
# Accuracy: 95.3125%
# Accuracy: 89.0625%
# Accuracy: 82.8125%
# Accuracy: 93.75%
# Accuracy: 85.9375%
# Accuracy: 92.1875%
# Accuracy: 84.375%
# Accuracy: 92.1875%
# Accuracy: 87.5%
# Accuracy: 81.25%
# Accuracy: 82.8125%
# Accuracy: 90.625%
# Accuracy: 89.0625%
# Accuracy: 81.25%
# Accuracy: 84.375%
# Accuracy: 81.25%
# Accuracy: 87.5%
# Accuracy: 85.9375%
# Accuracy: 87.5%
# Accuracy: 87.5%
# Accuracy: 90.625%
# Accuracy: 95.3125%
# Accuracy: 90.625%
# Accuracy: 87.5%
# Accuracy: 87.5%
# Accuracy: 92.1875%
# Accuracy: 81.25%
# Accuracy: 89.0625%
# Accuracy: 82.8125%
# Accuracy: 92.1875%
# Accuracy: 82.8125%
# Accuracy: 90.625%
# Accuracy: 89.0625%
# Accuracy: 87.5%
# Accuracy: 85.9375%
# Accuracy: 82.8125%
# Accuracy: 89.0625%
# Accuracy: 95.3125%
# Accuracy: 87.5%
# Accuracy: 92.1875%
# Accuracy: 89.0625%
# Accuracy: 90.625%
# Accuracy: 89.0625%
# Accuracy: 84.375%
# Accuracy: 90.625%
# Accuracy: 92.1875%
# Accuracy: 89.0625%
# Accuracy: 93.75%
# Accuracy: 84.375%
# Accuracy: 92.1875%
# Accuracy: 89.0625%
# Accuracy: 92.1875%
# Accuracy: 90.625%
# Accuracy: 85.9375%
# Accuracy: 85.9375%
# Accuracy: 82.8125%
# Accuracy: 89.0625%
# Accuracy: 95.3125%
# Accuracy: 89.0625%
# Accuracy: 81.25%
# Accuracy: 87.5%
# Accuracy: 90.625%
# Accuracy: 92.1875%
# Accuracy: 89.0625%
# Accuracy: 87.5%
# Accuracy: 89.0625%
# Accuracy: 90.625%
# Accuracy: 87.5%
# Accuracy: 85.9375%
# Accuracy: 82.8125%
# Accuracy: 93.75%
# Accuracy: 92.1875%
# Accuracy: 85.9375%
# Accuracy: 81.25%
# Accuracy: 85.9375%
# Accuracy: 84.375%
# Accuracy: 81.25%
# Accuracy: 89.0625%
# Accuracy: 85.9375%
# Accuracy: 87.5%
# Accuracy: 87.5%
# Accuracy: 90.625%
# Accuracy: 90.625%
# Accuracy: 95.3125%
# Accuracy: 89.0625%
# Accuracy: 89.0625%
# Accuracy: 93.75%
# Accuracy: 87.5%
# Accuracy: 85.9375%
# Accuracy: 92.1875%
# Accuracy: 85.9375%
# Accuracy: 85.9375%
# Accuracy: 82.8125%
# Accuracy: 76.5625%
# Accuracy: 87.5%
# Accuracy: 89.0625%
# Accuracy: 85.9375%
# Accuracy: 89.0625%
# Accuracy: 85.9375%
# Accuracy: 84.375%
# Accuracy: 78.125%
# Accuracy: 89.0625%
# Accuracy: 92.1875%
# Accuracy: 87.5%
# Accuracy: 87.5%
# Accuracy: 90.625%
# Accuracy: 81.25%
# Accuracy: 87.5%
# Accuracy: 82.8125%
# Accuracy: 90.625%
# Accuracy: 90.625%
# Accuracy: 92.1875%
# Accuracy: 92.1875%
# Accuracy: 89.0625%
# Accuracy: 89.0625%
# Accuracy: 90.625%
# Accuracy: 85.9375%
# Accuracy: 90.625%
# Accuracy: 92.1875%
# Accuracy: 87.5%
# Accuracy: 89.0625%
# Accuracy: 89.0625%
# Accuracy: 87.5%
# Accuracy: 95.3125%
# Accuracy: 93.75%
# Accuracy: 82.8125%
# Accuracy: 85.9375%
# Accuracy: 90.625%
# Accuracy: 84.375%
# Accuracy: 85.9375%
# Accuracy: 85.9375%
# Accuracy: 82.8125%
# Accuracy: 92.1875%
# Accuracy: 81.25%
# Accuracy: 90.625%
# Accuracy: 87.5%
# Accuracy: 92.1875%
# Accuracy: 82.8125%
# Accuracy: 85.9375%
# Accuracy: 87.5%
# Accuracy: 85.9375%
# Accuracy: 89.0625%
# Accuracy: 78.125%
# Accuracy: 89.0625%
# Accuracy: 89.0625%
# Accuracy: 95.3125%
# Accuracy: 87.5%
# Accuracy: 87.5%
# Accuracy: 87.5%
# Accuracy: 90.625%
# Accuracy: 85.9375%
# Accuracy: 90.625%
# Accuracy: 92.1875%
# Accuracy: 90.625%
# Accuracy: 85.9375%
# Accuracy: 95.3125%
# Accuracy: 90.625%
# Accuracy: 93.75%
# Accuracy: 87.5%
# Accuracy: 85.9375%
# Accuracy: 89.0625%
# Accuracy: 89.0625%
# Accuracy: 78.125%
# Accuracy: 96.875%
# Accuracy: 85.9375%
# Accuracy: 90.625%
# Accuracy: 89.0625%
# Accuracy: 87.5%
# Accuracy: 90.625%
# Accuracy: 82.8125%
# Accuracy: 89.0625%
# Accuracy: 84.375%
# Accuracy: 81.25%
# Accuracy: 82.8125%
# Accuracy: 92.1875%
# Accuracy: 90.625%
# Accuracy: 89.0625%
# Accuracy: 87.5%
# Accuracy: 87.5%
# Accuracy: 89.0625%
# Accuracy: 84.375%
# Accuracy: 85.9375%
# Accuracy: 92.1875%
# Accuracy: 89.0625%
# Accuracy: 85.9375%
# Accuracy: 92.1875%
# Accuracy: 81.25%
# Accuracy: 84.375%
# Accuracy: 84.375%
# Accuracy: 87.5%
# Accuracy: 87.5%
# Accuracy: 82.8125%
# Accuracy: 92.1875%
# Accuracy: 85.9375%
# Accuracy: 85.9375%
# Accuracy: 90.625%
# Accuracy: 85.9375%
# Accuracy: 90.625%
# Accuracy: 85.9375%
# Accuracy: 78.125%
# Accuracy: 87.5%
# Accuracy: 90.625%
# Accuracy: 93.75%
# Accuracy: 89.0625%
# Accuracy: 79.6875%
# Accuracy: 89.0625%
# Accuracy: 89.0625%
# Accuracy: 85.9375%
# Accuracy: 89.0625%
# Accuracy: 82.8125%
# Accuracy: 89.0625%
# Accuracy: 84.375%
# Accuracy: 87.5%
# Accuracy: 82.8125%
# Accuracy: 82.8125%
# Accuracy: 93.75%
# Accuracy: 89.0625%
# Accuracy: 93.75%
# Accuracy: 85.9375%
# Accuracy: 89.0625%
# Accuracy: 92.1875%
# Accuracy: 92.1875%
# Accuracy: 89.0625%
# Accuracy: 84.375%
# Accuracy: 87.5%
# Accuracy: 89.0625%
# Accuracy: 90.625%
# Accuracy: 84.375%
# Accuracy: 89.0625%
# Accuracy: 92.1875%
# Accuracy: 82.8125%
# Accuracy: 89.0625%
# Accuracy: 87.5%
# Accuracy: 92.1875%
# Accuracy: 85.9375%
# Accuracy: 90.625%
# Accuracy: 90.625%
# Accuracy: 82.8125%
# Accuracy: 92.1875%
# Accuracy: 90.625%
# Accuracy: 89.0625%
# Accuracy: 92.1875%
# Accuracy: 87.5%
# Accuracy: 78.125%
# Accuracy: 87.5%
# Accuracy: 87.5%
# Accuracy: 90.625%
# Accuracy: 90.625%
# Accuracy: 84.375%
# Accuracy: 93.75%
# Accuracy: 87.5%
# Accuracy: 81.25%
# Accuracy: 81.25%
# Accuracy: 84.375%
# Accuracy: 89.0625%
# Accuracy: 87.5%
# Accuracy: 85.9375%
# Accuracy: 89.0625%
# Accuracy: 93.75%
# Accuracy: 89.0625%
# Accuracy: 90.625%
# Accuracy: 84.375%
# Accuracy: 89.0625%
# Accuracy: 93.75%
# Accuracy: 92.1875%
# Accuracy: 85.9375%
# Accuracy: 87.5%
# Accuracy: 89.0625%
# Accuracy: 93.75%
# Accuracy: 85.9375%
# Accuracy: 84.375%
# Accuracy: 81.25%
# Accuracy: 85.9375%
# Accuracy: 89.0625%
# Accuracy: 93.75%
# Accuracy: 85.9375%
# Accuracy: 85.9375%
# Accuracy: 89.0625%
# Accuracy: 82.8125%
# Accuracy: 92.1875%
# Accuracy: 87.5%
# Accuracy: 92.1875%
# Accuracy: 85.9375%
# Accuracy: 92.1875%
# Accuracy: 92.1875%
# Accuracy: 87.5%
# Accuracy: 90.625%
# Accuracy: 90.625%
# Accuracy: 82.8125%
# Accuracy: 84.375%
# Accuracy: 84.375%
# Accuracy: 87.5%
# Accuracy: 81.25%
# Accuracy: 85.9375%
# Accuracy: 87.5%
# Accuracy: 89.0625%
# Accuracy: 90.625%
# Accuracy: 89.0625%
# Accuracy: 89.0625%
# Accuracy: 92.1875%
# Accuracy: 87.5%
# Accuracy: 85.9375%
# Accuracy: 81.25%
# Accuracy: 87.5%
# Accuracy: 89.0625%
# Accuracy: 84.375%
# Accuracy: 78.125%
# Accuracy: 87.5%
# Accuracy: 85.9375%
# Accuracy: 84.375%
# Accuracy: 95.3125%
# Accuracy: 82.8125%
# Accuracy: 79.6875%
# Accuracy: 85.9375%
# Accuracy: 87.5%
# Accuracy: 89.0625%
# Accuracy: 90.625%
# Accuracy: 92.1875%
# Accuracy: 89.0625%
# Accuracy: 96.875%
# Accuracy: 87.5%
# Accuracy: 84.375%
# Accuracy: 89.0625%
# Accuracy: 95.3125%
# Accuracy: 87.5%
# Accuracy: 85.9375%
# Accuracy: 84.375%
# Accuracy: 90.625%
# Accuracy: 93.75%
# Accuracy: 87.5%

# %% [markdown]
# ## Overfitting
#
# If we look at the training and validation losses as we train the network, we can see a phenomenon known as overfitting.
#
# <img src='assets/overfitting.png' width=450px>
#
# The network learns the training set better and better, resulting in lower training losses. However, it starts having problems generalizing to data outside the training set leading to the validation loss increasing. The ultimate goal of any deep learning model is to make predictions on new data, so we should strive to get the lowest validation loss possible. One option is to use the version of the model with the lowest validation loss, here the one around 8-10 training epochs. This strategy is called *early-stopping*. In practice, you'd save the model frequently as you're training then later choose the model with the lowest validation loss.
#
# The most common method to reduce overfitting (outside of early-stopping) is *dropout*, where we randomly drop input units. This forces the network to share information between weights, increasing it's ability to generalize to new data. Adding dropout in PyTorch is straightforward using the [`nn.Dropout`](https://pytorch.org/docs/stable/nn.html#torch.nn.Dropout) module.
#
# ```python
# class Classifier(nn.Module):
#     """Classifier network with dropout."""
#     def __init__(self):
#         super().__init__()
#         self.fc1 = nn.Linear(784, 256)
#         self.fc2 = nn.Linear(256, 128)
#         self.fc3 = nn.Linear(128, 64)
#         self.fc4 = nn.Linear(64, 10)
#
#         # Dropout module with 0.2 drop probability
#         self.dropout = nn.Dropout(p=0.2)
#
#     def forward(self, x):
#         """ Forward pass through the network, returns the output logits."""
#         # make sure input tensor is flattened
#         x = x.view(x.shape[0], -1)
#
#         # Now with dropout
#         x = self.dropout(F.relu(self.fc1(x)))
#         x = self.dropout(F.relu(self.fc2(x)))
#         x = self.dropout(F.relu(self.fc3(x)))
#
#         # output so no dropout here
#         x = F.log_softmax(self.fc4(x), dim=1)
#
#         return x
# ```
#
# During training we want to use dropout to prevent overfitting, but during inference we want to use the entire network. So, we need to turn off dropout during validation, testing, and whenever we're using the network to make predictions. To do this, you use `model.eval()`. This sets the model to evaluation mode where the dropout probability is 0. You can turn dropout back on by setting the model to train mode with `model.train()`. In general, the pattern for the validation loop will look like this, where you turn off gradients, set the model to evaluation mode, calculate the validation loss and metric, then set the model back to train mode.
#
# ```python
# # turn off gradients
# with torch.no_grad():
#
#     # set model to evaluation mode
#     model.eval()
#
#     # validation pass here
#     for images, labels in testloader:
#         ...
#
# # set model back to train mode
# model.train()
# ```

# %% [markdown]
# > **Exercise:** Add dropout to your model and train it on Fashion-MNIST again. See if you can get a lower validation loss or higher accuracy.

# %% [markdown]
# # We used CrossEntropyLoss for this one.
#
# ### Check out below for L_SoftMax and NLLLoss

# %%
## TODO: Define your model with dropout added
from torch import nn, optim
import torch.nn.functional as F

class model(nn.Module):
    def __init__(self):
        super().__init__()
        self.fc1 = nn.Linear(784, 256)
        self.fc2 = nn.Linear(256, 128)
        self.fc3 = nn.Linear(128, 64)
        self.fc4 = nn.Linear(64, 10)

        self.dropout = nn.Dropout(p = 0.2)

    def forward(self, x):
        x = self.dropout(F.relu(self.fc1(x)))
        x = self.dropout(F.relu(self.fc2(x)))
        x = self.dropout(F.relu(self.fc3(x)))
        x = self.fc4(x)

        return x

# %%
## TODO: Train your model with dropout, and monitor the training progress with the validation loss and accuracy
model = model()
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr = 0.003)

epochs = 8
steps = 0

train_losses, test_losses = [], []
for _ in range(epochs):
    running_loss = 0
    for images, labels in trainloader:
        images = images.view(images.shape[0], -1)
        optimizer.zero_grad()

        log_ps = model(images)
        loss = criterion(log_ps, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item()
    
    else:
        with torch.no_grad():
            model.eval()
            accuracy = 0
            for images, labels in testloader:
                images = images.view(images.shape[0], -1)

                logits = model(images)
                preds = logits.argmax(dim=1)
                accuracy += (preds == labels).float().mean().item()

        print(f"Accuracy: {accuracy / len(testloader) * 100:.2f}%")
        model.train()
# Out:
# Accuracy: 82.30%
# Accuracy: 83.47%
# Accuracy: 84.73%
# Accuracy: 85.22%
# Accuracy: 86.18%
# Accuracy: 85.84%
# Accuracy: 86.13%
# Accuracy: 86.31%

# %% [markdown]
# ## Inference
#
# Now that the model is trained, we can use it for inference. We've done this before, but now we need to remember to set the model in inference mode with `model.eval()`. You'll also want to turn off autograd with the `torch.no_grad()` context.

# %%
# Import helper module (should be in the repo)
import helper

# Test out your network!

model.eval()

dataiter = iter(testloader)
images, labels = next(dataiter)
img = images[0]
# Convert 2D image to 1D vector
img = img.view(1, 784)

# Calculate the class probabilities (softmax) for img
with torch.no_grad():
    output = model.forward(img)

ps = F.softmax(output, dim = 1)

# Plot the image and probabilities
helper.view_classify(img.view(1, 28, 28), ps, version="Fashion")

# %% [markdown]
# ## Next Up!
#
# In the next part, I'll show you how to save your trained models. In general, you won't want to train a model every time you need it. Instead, you'll train once, save it, then load the model when you want to train more or use if for inference.

# %% [markdown]
# # TRIED AGAIN WITH NLL and L_SoftMax

# %%
from torch import nn, optim
import torch.nn.functional as F

class model2(nn.Module):
    def __init__(self):
        super().__init__()
        self.fc1 = nn.Linear(784, 256)
        self.fc2 = nn.Linear(256, 128)
        self.fc3 = nn.Linear(128, 64)
        self.fc4 = nn.Linear(64, 10)

        self.dropout = nn.Dropout(p = 0.1)

    def forward(self, x):
        x = self.dropout(F.relu(self.fc1(x)))
        x = self.dropout(F.relu(self.fc2(x)))
        x = self.dropout(F.relu(self.fc3(x)))
        x = F.log_softmax(self.fc4(x), dim = 1)

        return x

# %%
from torch import nn, optim
import torch.nn.functional as F
net = model2()
criterion = nn.NLLLoss()
optimizer = optim.Adam(net.parameters(), lr = 0.0027)
epochs = 10
step = 0

train_losses, test_losses = [], []

for _ in range(epochs):
    running_loss = 0
    for images, labels in trainloader:
        images = images.view(images.shape[0], -1)
        optimizer.zero_grad()

        output = net(images)
        loss = criterion(output, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item()

    else:
        with torch.no_grad():
            net.eval()
            accuracy = 0
            for images, labels in testloader:
                images = images.view(images.shape[0], -1)

                log_ps = net(images)
                ps = torch.exp(log_ps)
                top_p, top_class = ps.topk(1, dim=1)

                equals = top_class.squeeze(1) == labels
                accuracy += equals.float().mean().item()
                
        print(f"Accuracy: {accuracy / len(testloader) * 100:.2f}%")
        net.train()
# Out:
# Accuracy: 84.78%
# Accuracy: 84.31%
# Accuracy: 85.20%
# Accuracy: 85.08%
# Accuracy: 85.85%
# Accuracy: 85.75%
# Accuracy: 86.56%
# Accuracy: 87.12%
# Accuracy: 87.31%
# Accuracy: 87.22%

# %%
# Import helper module (should be in the repo)
import helper

# Test out your network!

net.eval()

dataiter = iter(testloader)
images, labels = next(dataiter)
img = images[0]
# Convert 2D image to 1D vector
img = img.view(1, 784)

# Calculate the class probabilities (softmax) for img
with torch.no_grad():
    output = net.forward(img)

ps = torch.exp(output)

# Plot the image and probabilities
helper.view_classify(img.view(1, 28, 28), ps, version="Fashion")

# %%
model2.state_dict()
# Out:
# OrderedDict([('fc1.weight',
#               tensor([[ 0.0619,  0.0248,  0.0772,  ...,  0.0259,  0.0336,  0.0583],
#                       [ 0.1185,  0.1341,  0.1675,  ...,  0.1797,  0.1794,  0.1791],
#                       [ 0.1494,  0.0891,  0.0819,  ...,  0.1559,  0.2122,  0.1252],
#                       ...,
#                       [ 0.0725,  0.0745,  0.1189,  ...,  0.1312,  0.0946,  0.0915],
#                       [ 0.0159, -0.0355, -0.1035,  ..., -0.1122, -0.0148,  0.0076],
#                       [ 0.1426,  0.1762,  0.1777,  ...,  0.1394,  0.1564,  0.1446]])),
#              ('fc1.bias',
#               tensor([-0.0535, -0.1148, -0.1030, -0.0771, -0.2127, -0.0515, -0.0722, -0.1589,
#                         2.3891e-02,  8.6701e-02, -1.1432e-01, -2.5113e-01, -1.1277e-01,
#                        -4.1798e-01,  1.1021e-01,  6.0738e-02,  8.9638e-02, -1.4673e-02,
#                        -2.5132e-01, -2.3890e-01,  8.8826e-03,  1.1730e-01, -2.7043e-01,
#                         1.2755e-01,  1.1290e-02, -7.7104e-02,  1.1108e-01, -1.9621e-01,
#                        -1.1992e-01, -6.4043e-02,  1.0332e-01, -7.8046e-02, -2.1304e-01,
#                        -2.8701e-01,  1.5348e-01, -2.3475e-01, -3.2883e-01, -6.8912e-02,
#                         1.3146e-01,  1.2179e-01, -2.0426e-01, -3.5643e-01, -1.8251e-01,
#                        -2.1935e-01, -2.5469e-01, -2.1139e-01,  7.1468e-02, -1.6519e-01,
#                         3.1759e-02,  8.3393e-02, -5.2090e-02,  5.9006e-02, -2.0975e-01,
#                        -8.2036e-02, -2.7458e-02, -2.1845e-01, -7.1895e-02, -9.3314e-02,
#                        -5.1076e-02, -2.4565e-02,  6.3433e-02,  3.1429e-02, -3.0218e-01,
#                        -5.9677e-02, -2.0328e-01, -1.5260e-01, -2.8468e-01],
#                       [-9.2328e-01, -1.0226e-01,  5.7375e-02, -2.0184e-02,  3.1941e-02,
#                        -7.0928e-02, -1.4004e-01,  1.4069e-01, -3.9009e-01, -6.1923e-01,
#                        -4.6682e-01, -4.0037e-01, -1.0414e+00, -2.5205e-01, -3.1459e-01,
#                         6.3730e-02, -2.8008e-01, -6.9386e-03, -1.1816e-01,  1.3222e-01,
#                        -1.3324e-01,  9.9932e-04, -1.0062e+00, -3.2232e-01, -6.9656e-02,
#                         1.1529e-01, -7.7156e-01, -1.0842e-01,  6.6926e-02, -2.4443e-01,
#                        -6.1336e-01, -3.9918e-01, -7.8407e-01, -6.1926e-01,  1.2214e-01,
#                        -1.5132e-01, -7.3199e-01, -7.4265e-01, -1.7836e-02, -4.3931e-01,
#                         6.2279e-02, -3.3049e-01,  3.1236e-02, -3.2975e-01,  1.5963e-01,
#                        -1.8540e-01, -2.4476e-01, -3.3221e-01,  1.0941e-01,  1.2569e-01,
#                        -4.8976e-01, -4.9950e-02, -1.5330e-01, -2.2577e-01, -1.2003e-01,
#                        -7.8012e-02,  1.0479e-01, -1.9587e-04,  1.7421e-02, -4.9990e-01,
#                        -8.7867e-02,  1.1939e-01, -6.5510e-01, -1.3486e-01]])),
#              ('fc4.bias',
#               tensor([-0.1453, -0.7737,  0.2219,  0.2342,  0.0599, -0.0880,  0.0480,  0.2217,
#                        0.3451, -0.3322]))])

# %%
torch.save(model2.state_dict(), "Model2Module5.pth")

# %%
net = model2()  # or Model2() if you rename the class
net.load_state_dict(torch.load("Model2Module5.pth", map_location="cpu"))
net.eval()
# Out:
# model2(
#   (fc1): Linear(in_features=784, out_features=256, bias=True)
#   (fc2): Linear(in_features=256, out_features=128, bias=True)
#   (fc3): Linear(in_features=128, out_features=64, bias=True)
#   (fc4): Linear(in_features=64, out_features=10, bias=True)
#   (dropout): Dropout(p=0.1, inplace=False)
# )
